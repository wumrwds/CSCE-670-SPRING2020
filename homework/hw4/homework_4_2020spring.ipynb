# %% [markdown]
# #### CSCE 670 :: Information Storage and Retrieval :: Texas A&M University :: Spring 2020
#
#
# # Homework 4:  Word Embeddings for Information Retrieval and Query Expansion
#
# ### 100 points [5% of your final grade]
#
# ### Due: April 28, 2020 by 11:59pm
#
# *Goals of this homework:* In this homework you will improve your information retrieval engine in homework 1 by word embeddings to: (i) directly match the query and the document in the latent semantic space of word embeddings; (ii) expand the original query via word embeddings.
#
# *Submission instructions (eCampus):* To submit your homework, rename this notebook as `UIN_hw4.ipynb`. For example, my homework submission would be something like `555001234_hw4.ipynb`. Submit this notebook via eCampus (look for the homework 1 assignment there). Your notebook should be completely self-contained, with the results visible in the notebook. We should not have to run any code from the command line, nor should we have to run your code within the notebook (though we reserve the right to do so). So please run all the cells for us, and then submit.
#
# *Late submission policy:* For this homework, you may use as many late days as you like (up to the total allotted to you).
#
# *Collaboration policy:* You are expected to complete each homework independently. Your solution should be written by you without the direct aid or help of anyone else. However, we believe that collaboration and team work are important for facilitating learning, so we encourage you to discuss problems and general problem approaches (but not actual solutions) with your classmates. You may post on Piazza, search StackOverflow, etc. But if you do get help in this way, you must inform us by **filling out the Collaboration Declarations at the bottom of this notebook**.
#
# *Example: I found helpful code on stackoverflow at https://stackoverflow.com/questions/11764539/writing-fizzbuzz that helped me solve Problem 2.*
#
# The basic rule is that no student should explicitly share a solution with another student (and thereby circumvent the basic learning process), but it is okay to share general approaches, directions, and so on. If you feel like you have an issue that needs clarification, feel free to contact either me or the TA.

# %% [markdown]
# ## Part 0. Dataset and Parsing (The same as Homework 1)
#
# The dataset is collected from Quizlet (https://quizlet.com), a website where users can generated their own flashcards. Each flashcard generated by a user is made up of an entity on the front and a definition describing or explaining the entity correspondingly on the back. We treat entities on each flashcard's front as the queries and the definitions on the back of flashcards as the documents. Definitions (documents) are relevant to an entity (query) if the definitions are from the back of the entity's flashcard; otherwise definitions are not relevant. **In this homework, queries and entities are interchangeable as well as documents and definitions.**
#
# The format of the dataset is like this:
#
# **query \t document id \t document**
#
# Examples:
#
# decision tree	\t 27946 \t	show complex processes with multiple decision rules.  display decision logic (if statements) as set of (nodes) questions and branches (answers).
#
# where "decision tree" is the entity in the front of a flashcard and "show complex processes with multiple decision rules.  display decision logic (if statements) as set of (nodes) questions and branches (answers)." is the definition on the flashcard's back and "27946" is the id of the definition. Naturally, this document is relevant to the query.
#
# false positive rate	\t 686	\t fall-out; probability of a false alarm
#
# where document 686 is not relevant to query "decision tree" because the entity of "fall-out; probability of a false alarm" is "false positive rate".
#
# For parsing this dataset, you could also just copy your code from homework 1 to complete the following tasks:
# * Tokenize documents (definitions) using **whitespaces and punctuations as delimiters**.
# * Remove stop words: use nltk stop words list (from nltk.corpus import stopwords)
# * Stemming: use [nltk Porter stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.porter)
# * Remove any other strings that you think are less informative or nosiy.

# %%
import re
import numpy as np
import pandas as pd
import math

from nltk.corpus import stopwords
from nltk.stem.porter import *
from pandas import DataFrame, Series
from collections import defaultdict
from sklearn.preprocessing import normalize

# %%
# configuration options
remove_stopwords = True  # or false
use_stemming = True # or false
remove_otherNoise = True # or false

# %%
stop_words = set(stopwords.words('english'))

# load data
filename = "homework_4_data.txt"
with open(filename) as f:
    content = f.readlines()

# split data into 3 columns and convert it to a dataframe
documents = np.array([re.split("\t", x) for x in content])
documents_df = pd.DataFrame(documents, columns=["entity", "id", "definition"])

# %%
def count_unique_words(definitions: Series):
    distinct_set = set()
    
    for index, value in definitions.items():
        distinct_set.update(value)
    
    return len(distinct_set)

def stem_tokens(tokens):
    stemmer = PorterStemmer()
    return np.array([stemmer.stem(token) for token in tokens])

def parse(definitions: Series, remove_stopwords: bool = True, 
          use_stemming: bool = True, remove_otherNoise: bool = True,
         show_log = True):
    definitions = definitions.apply(lambda x: re.split("\W+", x.strip()))
    
    if show_log:        
        print("None of pre-processing options =", count_unique_words(definitions))
    
    # remove stopwords
    if remove_stopwords:
        def rm_stopwords(tokens):
            removed = []
            for w in tokens:
                if w not in stop_words:
                    removed.append(w)
            return removed
        
        definitions = definitions.apply(rm_stopwords)
        if show_log:
            print("After removing stop words =", count_unique_words(definitions))

    # do stemming
    if use_stemming:
        stemmer = PorterStemmer()
        
        def stem(tokens):
            return [stemmer.stem(token) for token in tokens]
        
        definitions = definitions.apply(stem)
        if show_log:
            print("After removing stop words + stemming =", count_unique_words(definitions))
        
    # remove noise        
    if remove_otherNoise:
        def rm_noise(tokens):
            removed = []
            # to lower case, then remove digits and empty strings
            for w in tokens:
                w = w.lower()
                if not w.isdigit() and w.strip():
                    removed.append(w)
            return removed
                
        definitions = definitions.apply(rm_noise)
        if show_log:
            print("After removing stop words + stemming + removing other noise = %i \n" % count_unique_words(definitions))
    
    return definitions

# %%
# parse definitions
documents_df = documents_df.assign(tokens=parse(documents_df['definition'], 
                                                remove_stopwords=remove_stopwords, 
                                                use_stemming=use_stemming, 
                                                remove_otherNoise=remove_otherNoise))
# Out:
# None of pre-processing options = 15939
# After removing stop words = 15799
# After removing stop words + stemming = 9921
# After removing stop words + stemming + removing other noise = 9654

# %%
# show parsed documents dataframe
documents_df
# Out:
#                      entity     id  \
# 0        bottom-up approach      0
# 1        bottom-up approach      1
# 2        bottom-up approach      2
# 3        bottom-up approach      3
# 4        bottom-up approach      4
# ...                     ...    ...
# 30912  sensitivity analysis  30912
# 30913     memory controller  30913
# 30914     memory controller  30914
# 30915     memory controller  30915
# 30916     memory controller  30916
#
#                                               definition  \
# 0      estimates of duration and cost are made for ea...
# 1      pattern from process  deductive approach  use ...
# 2                                   normalization; 3nf\n
# 3                             client factor standpoint\n
# 4      approach for dynamic programming problems, whi...
# ...                                                  ...
# 30912  understand changes in the analysis outcome if ...
# 30913  the chip that manages access to the ram and a ...
# 30914                 chip that manages access to ram.\n
# 30915  this handles dram accesses by converting reque...
# 30916  to improve performance, some processors includ...
#
#                                                   tokens
# 0      [estim, durat, cost, made, compon, separ, comb...
# 1      [pattern, process, deduct, approach, use, unde...
# 2                                          [normal, 3nf]
# 3                           [client, factor, standpoint]
# 4      [approach, dynam, program, problem, problem, s...
# ...                                                  ...
# 30912  [understand, chang, analysi, outcom, case, ass...
# 30913  [chip, manag, access, ram, other, comm, direct...
# 30914                         [chip, manag, access, ram]
# 30915  [handl, dram, access, convert, request, proces...
# 30916  [improv, perform, processor, includ, memori, c...
#
# [30917 rows x 4 columns]

# %% [markdown]
# # Part 1: Word2Vec (30 points)
#
# In this part you will use the Word2Vec algorithm to generate word embeddings for tokens in the dataset. You can just use a package like https://radimrehurek.com/gensim/models/word2vec.html. Let's set the size of word embeddings to be 20. Please print the word embeddings for the tokens:
# * relational
# * database
# * garbage
# * collection
# * retrieval
# * model

# %%
# code here.
# how do you generate the word embeddings

# %%
from gensim.models import word2vec as w2v

# %%
tokens_array = documents_df['tokens']

# %%
# build the model and the vocabulary
model = w2v.Word2Vec(min_count=1, window=6, size=20, alpha=0.03, min_alpha=0.0007, negative=20, workers=8)
model.build_vocab(tokens_array)

# %%
# train the Word2Vec model
model.train(tokens_array, total_examples=model.corpus_count, epochs=30)
# Out:
# (10034490, 11106000)

# %%
original_tokens = ['relational', 'database', 'garbage', 'collection', 'retrieval', 'model']
stemmed_tokens = stem_tokens(original_tokens)
stemmed_tokens
# Out:
# array(['relat', 'databas', 'garbag', 'collect', 'retriev', 'model'],
#       dtype='<U7')

# %%
# print the word embeddings of the six tokens
for i in range(len(original_tokens)):
    print("The word embedding of '%s': \n%s\n" % (original_tokens[i], model.wv[stemmed_tokens[i]]))
# Out:
# The word embedding of 'relational':
# [ 3.987224    0.99150014 -0.2030409   5.1891437   0.03617263  2.2877784
#  -1.498411    1.7737788   1.658147    0.44948825  2.339248   -4.111205
#  -3.6118011   3.4931428  -1.1895815   2.4489295  -3.6807873   1.4104651
#  -0.97014517  1.9691614 ]
#
# The word embedding of 'database':
# [ 1.0722051  -2.3072646   1.2980088   0.13472337 -2.1487749   1.5096837
#  -5.710013    5.101156    3.853077    0.73120254 -1.1705676  -4.029453
#  -3.2424946   1.9834421  -1.2421125   1.5238795  -5.9608893   0.08506732
#  -2.6960568   0.04874504]
#
# The word embedding of 'garbage':
# [ 0.5175103  -0.19416364 -0.38053524  0.27035043  0.382551   -1.7212878
#  -1.775694   -0.5677808   0.38113728  0.93155485 -0.57317287  0.08332677
#   2.1163151  -0.6121957  -1.3398107  -0.15714733 -0.3113945   1.4265146
#  -2.238204   -0.33334285]
#
# The word embedding of 'collection':
# [ 2.5483363   2.5248249   0.61709976  0.3526393  -0.30008832  0.4942185
#  -2.6464262   2.7307284   6.9969535   2.3407018   2.183731   -1.483314
#  -1.5320069   3.3188558   3.0637276   0.88925827 -3.986852    1.0218948
#  -0.6050631  -0.20336582]
#
# The word embedding of 'retrieval':
# [-1.9308951   3.0120249   2.4329324  -0.10259213 -5.4756455  -0.8530507
#  -5.4670787   3.7173204   6.9231124  -0.15492259  0.8343715  -1.7230272
#   1.0712551   0.94831485  0.07350373  2.8126905  -1.3945122   0.15315017
#  -3.163964   -0.60698885]
#
# The word embedding of 'model':
# [-1.6020855  -3.3003109   1.1680084   3.7767267   2.3346672   3.9585142
#  -1.0269188  -1.3541573   0.00702738  0.10330407  0.14931715 -3.4029458
#  -2.7829726   2.4658804  -1.499747   -1.9281458  -3.953786   -0.8539023
#   1.9067242  -2.471249  ]

# %% [markdown]
# # Part 2: Vector Space Model via Word Embeddings (40 points)
#
# In this part, your job is to match the query and the document via the cosine similarity between the embeddings of them.
#
# Since there are not just one token in a query or a document, the first challenge is how to aggregate many word embeddings into one embedding of a query or a document. There are many ways to do so:
# * Max pooling: return the maximum value along each dimension of a bunch of word embeddings. For example, [1, 3, 4], [2, 1, 5] -> [2, 3, 5].
# * Min pooling: return the minimum value along each dimension of a bunch of word embeddings
# * Mean pooling: return the mean value along each dimension of a bunch of word embeddings
# * Sum: element-wise add a bunch of word embeddings together
# * Weighted sum: assign weights to word embeddings and then add them together. Weights could be TF, IDF or TF-IDF.

# %%
# your code here
import math

from sklearn.preprocessing import normalize
from IPython.core.display import HTML


embedding_size = 20

# %%
def max_pooling_df(model, documents_df):
    def max_pooling(tokens):
        aggregated_embedding = np.zeros((embedding_size, ))
        for token in tokens:
            aggregated_embedding = np.maximum(aggregated_embedding, model.wv[token])
        return aggregated_embedding
    
    return documents_df["tokens"].apply(max_pooling)

def min_pooling_df(model, documents_df):
    def min_pooling(tokens):
        aggregated_embedding = np.zeros((embedding_size, ))
        for token in tokens:
            aggregated_embedding = np.minimum(aggregated_embedding, model.wv[token])
        return aggregated_embedding
    
    return documents_df["tokens"].apply(min_pooling)

def avg_pooling_df(model, documents_df):
    def avg_pooling(tokens):
        aggregated_embedding = np.zeros((embedding_size, ))
        print(tokens)
        if len(tokens) > 0:
            for token in tokens:
                aggregated_embedding = aggregated_embedding + model.wv[token]
            aggregated_embedding /= len(tokens)
        return aggregated_embedding
    
    return documents_df["tokens"].apply(avg_pooling)

def sum_pooling_df(model, documents_df):
    def sum_pooling(tokens):
        aggregated_embedding = np.zeros((embedding_size, ))
        for token in tokens:
            aggregated_embedding = aggregated_embedding + model.wv[token]
        return aggregated_embedding
    
    return documents_df["tokens"].apply(sum_pooling)

def get_df_dict(documents_df):
    # get vocabulary set
    vocabulary_set = set()
    for index, value in documents_df["tokens"].items():
        vocabulary_set.update(value)
    
    # get df dictionary for calculating tf-idf
    df_dict = dict()
    for token in vocabulary_set:
        df_dict[token] = documents_df["tokens"].apply(lambda tokens: 1 if token in tokens else 0).sum()
        
    return df_dict

def tf_idf_weighted_pooling_df(model, documents_df, df_dict):    
    N = documents_df.shape[0]
    def tf_idf_weighted_pooling(tokens):
        aggregated_embedding = np.zeros((embedding_size, ))
        for token in tokens:
            tf = tokens.count(token)
            df = df_dict[token]
            tf_idf = (1 + math.log10(tf)) * math.log10(N / df)
            aggregated_embedding += tf_idf * model.wv[token]
        return aggregated_embedding
    
    return documents_df["tokens"].apply(tf_idf_weighted_pooling)

# %%
# add columns of different pooling approaches
df_dict = get_df_dict(documents_df)
documents_df = documents_df.assign(max_pooling_embedding=max_pooling_df(model, documents_df))
documents_df = documents_df.assign(min_pooling_embedding=min_pooling_df(model, documents_df))
documents_df = documents_df.assign(avg_pooling_embedding=avg_pooling_df(model, documents_df))
documents_df = documents_df.assign(sum_pooling_embedding=sum_pooling_df(model, documents_df))
documents_df = documents_df.assign(tf_idf_weighted_pooling_embedding=tf_idf_weighted_pooling_df(model, documents_df, df_dict))
documents_df
# Out:
# ['estim', 'durat', 'cost', 'made', 'compon', 'separ', 'combin', 'provid', 'overal', 'figur']
# ['pattern', 'process', 'deduct', 'approach', 'use', 'understand', 'process', 'predict', 'pattern', 'emerg', 'individu', 'agent', 'base', 'model', 'macroscop', 'emerg', 'pattern', 'micro', 'level', 'behavior']
# ['normal', '3nf']
# ['client', 'factor', 'standpoint']
# ['approach', 'dynam', 'program', 'problem', 'problem', 'solut', 'compos', 'solut', 'problem', 'smaller', 'input']
# ['piec', 'togeth', 'system', 'give', 'rise', 'complex', 'system']
# ['piec', 'togeth', 'system', 'give', 'rise', 'grander', 'system']
# ['begin', 'look', 'process', 'directli', 'activ', 'level', 'aggreg', 'identifi', 'process', 'across', 'organ']
# ['begin', 'level', 'attribut', 'normal', 'bottom', 'use', 'small', 'databas', 'attribut']
# ['often', 'intuit', 'approach', 'use', 'recurs', 'dynam', 'program', 'start', 'know', 'solv', 'problem', 'simpl', 'case', 'like', 'list', 'one', 'element', 'figur', 'solv', 'problem', 'two', 'element', 'three', 'element', 'key', 'think', 'build', 'solut', 'one', 'case', 'previou', 'case', 'multipl', 'previou', 'case']
# ['staff', 'make', 'secur', 'decis', 'directli', 'without', 'input', 'senior', 'manag', 'rare', 'use']
# ['creat', 'wb', 'team', 'member', 'identifi', 'mani', 'specif', 'task', 'relat', 'project', 'possibl', 'group', 'higher', 'level', 'categori']
# ['formul', 'hypothesi', 'test', 'come', 'gener', 'conclus']
# ['independ', 'class', 'fulli', 'implement', 'test', 'incorpor', 'overal', 'project']
# ['induct', 'reason']
# ['base', 'understand', 'human', 'bodi', 'mechan']
# ['build', 'solut', 'one', 'case', 'previou', 'case']
# ['medic', 'approach', 'organ', 'substrat', 'first', 'level', 'capac', 'develop', 'capac']
# ['go', 'special', 'object', 'character', 'gener', 'object', 'gener']
# ['emphas', 'written', 'text', 'go', 'smallest', 'biggest', 'linguist', 'unit', 'identifi', 'letter', 'gt', 'word', 'gt', 'sentenc', 'gt', 'paragraph', 'gt', 'text']
# ['opposit', 'top', 'approach', 'bottom', 'approach', 'bottom', 'approach', 'environ', 'staff', 'make', 'secur', 'decis', 'directli', 'without', 'input', 'senior', 'manag', 'bottom', 'approach', 'rare', 'use', 'organ', 'consid', 'problemat', 'industri']
# ['approach', 'estim', 'fee', 'pm', 'begin', 'break', 'project', 'individu', 'task', 'estim', 'much', 'time', 'need', 'complet', 'one']
# ['break', 'project', 'individu', 'task', 'list', 'task', 'chronolog', 'order', 'estim', 'number', 'hour', 'complet', 'task', 'assign', 'staff', 'member', 'specif', 'bill', 'rate', 'task', 'calcul', 'total', 'estim', 'work', 'fee']
# ['process', 'defin', 'gener', 'entiti', 'type', 'set', 'special', 'entiti', 'type', 'normal']
# ['languag', 'learn', 'proce', 'basic', 'block', 'languag', 'word', 'proceed', 'complex', 'structur', 'final', 'mean']
# ['employe', 'redesign', 'job', 'increas', 'engag']
# ['use', 'distribut', 'system', 'techniqu', 'snif', 'network', 'traffic', 'reduc', 'sheer', 'amount', 'data', 'collect', 'use', 'sensor', 'grab', 'relev', 'data']
# ['run', 'detect', 'network', 'either', 'distribut', 'monitor', 'network', 'activ']
# ['rule', 'base', 'heurist', 'approach', 'command', 'line', 'base', 'interfac', 'need', 'know', 'command']
# ['process', 'specifi', 'detail', 'compon', 'inform', 'system', 'implement']
# ['third', 'five', 'phase', 'system', 'develop', 'life', 'cycl']
# ['system', 'accomplish', 'requir', 'input', 'hardwar', 'integr']
# ['build', 'tech', 'blueprint', 'system', 'work', 'tech']
# ['task', 'defin', 'system', 'accomplish', 'requir']
# ['describ', 'system', 'resolv', 'busi', 'problem', 'deliver', 'technic', 'system', 'specif']
# ['task', 'includ', 'output', 'user', 'interfac', 'design', 'data', 'design', 'system', 'architectur']
# ['system', 'oper', 'solv', 'problem']
# ['design', 'logic', 'physic', 'activ', 'implement', 'propos', 'system', 'design']
# ['system', 'develop', 'activ', 'enabl', 'person', 'describ', 'detail', 'result', 'inform', 'system', 'actual', 'implement']
# ['goal', 'build', 'system', 'effect', 'reliabl', 'maintain', 'effect', 'support', 'busi', 'requir', 'meet', 'user', 'need', 'reliabl', 'handl', 'input', 'error', 'process', 'error', 'hardwar', 'failur', 'human', 'mistak', 'maintain', 'flexibl', 'scalabl', 'easili', 'modifi']
# ['activ', 'enabl', 'person', 'defin', 'describ', 'detail', 'system', 'solv', 'need']
# ['provid', 'start', 'point', 'implement', 'system', 'design', 'system', 'analysi', 'document', 'coordin', 'work']
# ['describ', 'system', 'specif', 'deliv', 'function', 'identifi', 'system', 'analysi', 'address', 'manageri', 'organiz', 'technolog', 'compon', 'system', 'solut']
# ['show', 'flow', 'input', 'output', 'system']
# ['includ', 'three', 'step', 'devis', 'mean', 'meet', 'requir', 'descript', 'compon', 'construct', 'test']
# ['goal', 'system', 'design', 'build', 'system', 'effect', 'reliabl', 'maintain']
# ['activ', 'enabl', 'person', 'defin', 'describ', 'detail', 'system', 'solv', 'need', 'system', 'oper', 'solv', 'problem']
# ['preliminari', 'design', 'detail', 'design', 'write', 'report']
# ['describ', 'new', 'system', 'resolv', 'busi', 'problem', 'design', 'human', 'interfac', 'design', 'databas']
# ['step', 'system', 'develop', 'life', 'cycl', 'sdlc', 'logic', 'physic', 'compon', 'defin']
# ['step', 'meet', 'requir', 'descript', 'compon', 'construct', 'test']
# ['describ', 'desir', 'featur', 'oper', 'detail', 'includ', 'screen', 'layout', 'busi', 'rule', 'process', 'diagram', 'pseudocod', 'document']
# ['descript', 'main', 'compon', 'system', 'relationship', 'one', 'anoth', 'local', 'design', 'physic', 'design']
# ['logic', 'design', 'system', 'abstract', 'represent', 'flow', 'input', 'output', 'system']
# ['activ', 'enabl', 'person', 'describ', 'detail', 'system', 'solv', 'need']
# ['investig', 'record', 'exist', 'system', 'design', 'new', 'system']
# ['specifi', 'new', 'system', 'achiev', 'goal', 'better', 'old', 'system', 'within', 'budget']
# ['output', 'stage', 'gener', 'call', 'function', 'specif', 'document', 'document', 'describ', 'equip', 'softwar', 'use', 'develop', 'system']
# ['creat', 'new', 'system', 'solv', 'problem', 'opportun']
# ['describ', 'detail', 'system', 'solv', 'need']
# ['describ', 'system', 'resolv', 'busi', 'problem']
# ['creat', 'design', 'specif', 'ie', 'system', 'oper', 'address', 'problem']
# ['specif', 'detail', 'comput', 'base', 'solut', 'also', 'call', 'physic', 'design', 'system', 'analysi', 'emphas', 'busi', 'problem']
# ['third', 'phase', 'system', 'develop', 'life', 'cycl']
# ['creat', 'complet', 'set', 'technic', 'specif', 'use', 'construct', 'inform', 'system']
# ['stage', 'system', 'develop', 'creat', 'complet', 'set', 'technic', 'specif', 'use', 'construct', 'inform', 'system']
# ['defin', 'inform', 'system', 'need', 'reach', 'solut', 'select', 'plan', 'best', 'solut', 'easi', 'use', 'user']
# ['must', 'formul', 'blueprint', 'complet', 'system']
# ['system', 'develop', 'phase', 'defin', 'inform', 'system', 'must', 'obtain', 'solut']
# ['creat', 'logic', 'physic', 'compon']
# ['tailor', 'find', 'solut', 'search', 'space', 'infinit', 'big', 'fit', 'landscap', 'valu', 'continu', 'current', 'state', 'thing', 'matter']
# ['identifi', 'geograph', 'region', 'associ', 'web', 'page', 'order', 'provid', 'relev', 'result']
# ['solut', 'state']
# ['identifi', 'geograph', 'locat', 'associ', 'web', 'page', 'locat', 'metadata', 'locat', 'name', 'text', 'queri', 'contain', 'geograph', 'refer']
# ['path', 'goal', 'matter']
# ['type', 'search', 'keep', 'track', 'previou', 'state', 'instead', 'keep', 'track', 'current', 'state', 'use', 'method', 'gener', 'altern', 'solut', 'state', 'candid']
# ['gener', 'approach', 'solv', 'problem', 'compromis', 'larg', 'rang', 'algo', 'help', 'escap', 'expontenti', 'complex', 'mani', 'np', 'problem', 'iter', 'improv', 'start', 'solut', 'move', 'one', 'step', 'time', 'neighbor', 'solut', 'improv', 'solut', 'start', 'exist', 'solut', 'search', 'set', 'possibl', 'new', 'solut', 'within', 'current', 'solut', 'neighborhood', 'candid', 'list', 'determin', 'solut', 'use', 'place', 'current', 'solut', 'base', 'output', 'heurist', 'accept', 'candid', 'list', 'input', 'continu', 'step', 'see', 'improv', 'solut', 'best', 'solut', 'avail']
# ['care', 'solut', 'rather', 'path', 'goal', 'state', 'use', 'singl', 'current', 'node', 'move', 'neighbor', 'node', 'advantag', 'littl', 'memori', 'reason', 'sol', 'larg', 'infinit', 'space']
# ['state', 'space', 'set', 'complet', 'configur', 'current', 'state', 'maintain', 'iter', 'improv', 'goal', 'find', 'optim', 'state']
# ['use', 'optim', 'problem', 'use', 'object', 'function', 'find', 'solut', 'maxim', 'criterion', 'among', 'number', 'candid', 'solut', 'local', 'search', 'algorithm', 'move', 'solut', 'solut', 'space', 'candid', 'solut', 'search', 'space', 'appli', 'local', 'chang', 'solut', 'deem', 'optim', 'found', 'time', 'bound', 'elaps']
# ['want', 'find', 'end', 'state', 'matter', 'get', 'want', 'solut', 'care', 'path', 'need', 'import', 'piec', 'state', 'descript', 'contain', 'info', 'solut', 'use', 'one', 'current', 'node', 'move', 'neighbor', 'maintain', 'path']
# ['state', 'descript', 'contain', 'inform', 'solut', 'oper', 'use', 'singl', 'current', 'node', 'move', 'neighbor', 'node']
# ['store', 'deliv', 'request', 'webpag', 'comput', 'via', 'brows']
# ['comput', 'receiv', 'request', 'mani', 'differ', 'web', 'client', 'respond', 'send', 'html', 'file', 'back', 'web', 'client', 'comput']
# ['possibl', 'commonli', 'attack', 'server', 'ex', 'microsoft', 'internet', 'inform', 'servic', 'ii', 'apach', 'http', 'server', 'linux', 'lighttpd', 'freebsd', 'oracl', 'iplanet', 'web', 'server', 'oracl', 'iplanet', 'predecessor', 'sun', 'java', 'system', 'web', 'server', 'sun', 'microsystem', 'web', 'system', 'gener', 'victim', 'do', 'attack', 'overflow', 'xss', 'xsrf', 'remot', 'code', 'execut', 'variou', 'attack', 'make', 'use', 'backdoor', 'ex', 'ii', 'basic', 'authent', 'enabl', 'backdoor', 'could', 'creat', 'attack', 'could', 'ultim', 'bypass', 'access', 'restrict', 'ii', 'admin', 'must', 'keep', 'date', 'latest', 'vulner', 'read', 'microsoft', 'secur', 'bulletin']
# ['also', 'call', 'web', 'host', 'use', 'fetch', 'page', 'request', 'send', 'client', 'browser']
# ['program', 'prepackag', 'softwar', 'hardwar', 'applianc', 'embed', 'consum', 'product']
# ['serv', 'static', 'web', 'page', 'client', 'via', 'http', 'also', 'serv', 'dynam', 'content', 'ad', 'php', 'java', 'rubi', 'python', 'etc', 'apach', 'nginx', 'popular', 'web', 'server', 'websit', 'use', 'apach', 'nginx']
# ['internet', 'web', 'server', 'accept', 'http', 'port', 'request', 'client', 'web', 'browser', 'send', 'back', 'request', 'inform', 'client', 'common', 'form', 'server', 'internet', 'attack', 'attack', 'disrupt', 'user', 'form', 'access', 'inform', 'spread', 'worm', 'virus', 'replac', 'inform', 'popular', 'attack', 'malform', 'request', 'buffer', 'overflow', 'worm', 'do', 'attack']
# ['commonli', 'host', 'web', 'site', 'access', 'internet', 'also', 'server', 'page', 'within', 'intern', 'network']
# ['host', 'number', 'websit', 'webpag']
# ['host', 'compani', 'creat', 'one', 'domain']
# ['provid', 'web', 'page', 'public', 'view', 'public', 'domain', 'prime', 'target', 'hacker']
# ['program', 'process', 'http', 'protocol', 'transmit', 'web', 'page', 'demand', 'web', 'server', 'also', 'process', 'applic', 'program']
# ['web', 'server', 'could', 'commonli', 'attack', 'server', 'web', 'server', 'gener', 'victim', 'do', 'attack', 'overflow', 'xss', 'xsrf', 'remot', 'code', 'execut', 'variou', 'attack', 'make', 'use', 'backdoor', 'keep', 'date', 'cve', 'list', 'standard', 'updat', 'hot', 'patch', 'consid', 'ad', 'hardwar', 'base', 'firewal', 'cisco', 'junip', 'check', 'point', 'similar', 'compani', 'http', 'ssl', 'better', 'yet', 'tl']
# ['softwar', 'serv', 'web', 'resourc', 'softwar', 'client', 'web', 'server', 'typic', 'run', 'server', 'hardwar', 'howev', 'may', 'comput', 'devic', 'today', 'support', 'web', 'server', 'softwar']
# ['provid', 'secur', 'servic', 'ftp', 'search', 'engin', 'data', 'captur', 'analyt']
# ['document', 'web', 'store']
# ['isp', 'internet', 'servic', 'provid', 'host', 'servic', 'dedic', 'server', 'virtual', 'privat', 'server', 'vp', 'cloud', 'host', 'share', 'host', 'web', 'server', 'softwar', 'apach', 'apach', 'tomcat', 'microsoft', 'ii', 'internet', 'inform', 'servic', 'nginx']
# ['implement', 'server', 'side', 'http', 'hous', 'web', 'object', 'address', 'url', 'alway', 'fix', 'ip', 'address', 'servic', 'request', 'potenti', 'million', 'differ', 'browser']
# ['web', 'server', 'secur', 'often', 'overlook', 'stick', 'right', 'front', 'open', 'access', 'tri', 'best', 'secur', 'web', 'server', 'open', 'target', 'entir', 'world', 'see']
# ['web', 'site', 'associ', 'inform', 'store', 'use', 'recogn', 'inform', 'request', 'send', 'request', 'document']
# ['commun', 'mani', 'browser', 'time', 'use', 'http', 'process', 'respond', 'request', 'send', 'browser', 'web', 'page', 'html', 'stream', 'e', 'apach', 'linux', 'internet', 'inform', 'server', 'window', 'xp', 'profession']
# ['combin', 'softwar', 'tool', 'let', 'applic', 'softwar', 'one', 'organ', 'commun', 'applic', 'network', 'use', 'protocol']
# ['comput', 'provid', 'page', 'web', 'client', 'comput', 'host', 'web', 'page']
# ['web', 'server', 'typic', 'use', 'store', 'web', 'applic', 'web', 'servic', 'web', 'applic', 'design', 'run', 'web', 'server']
# ['store', 'inform', 'web', 'page', 'type', 'websit', 'address', 'browser', 'request', 'right', 'websit', 'file', 'web', 'server']
# ['server', 'side', 'script', 'run']
# ['nginx', 'apach', 'tomcat', 'gw', 'jboss']
# ['web', 'server', 'comput', 'run', 'special', 'softwar', 'allow', 'make', 'web', 'page', 'avail', 'other', 'protocol', 'http', 'apach', 'ii', 'internet', 'inform', 'servic', 'microsoft', 'popular', 'typic', 'run', 'dedic', 'machin', 'datacent', 'rack', 'connect', 'time', 'although', 'could', 'standard', 'pc']
# ['implement', 'server', 'side', 'http', 'hous', 'web', 'object', 'address']
# ['connect', 'use', 'webpag']
# ['hypertext', 'server']
# ['memori', 'graph', 'layout', 'graph']
# ['tool', 'use', 'help', 'analysi']
# ['support', 'activ', 'slice', 'cluster', 'featur', 'identif', 'domain', 'analysi', 'metric', 'calcul', 'etc']
# ['use', 'case', 'diagram', 'context', 'diagram', 'data', 'flow', 'diagram']
# ['tool', 'enabl', 'automat', 'check', 'incomplet', 'inconsist', 'incorrect', 'specif', 'diagram', 'form', 'report']
# ['run', 'time', 'algorithm', 'increas', 'faster', 'polynomi', 'function', 'input', 'size', 'unreason', 'run', 'time', 'would', 'increas', 'superpolynomiali']
# ['number', 'algorithm', 'step', 'less', 'equal', 'size', 'input']
# ['polynomi', 'number', 'step', 'algorithm', 'take', 'worst', 'case', 'base', 'input', 'size']
# ['view', 'term', 'input', 'output', 'without', 'knowledg', 'intern', 'work']
# ['examin', 'goe', 'method', 'detail', 'work', 'insid']
# ['blind', 'test', 'system']
# ['outsid', 'attack', 'attack', 'knowledg', 'network', 'environ']
# ['penetr', 'test', 'tester', 'prior', 'knowledg', 'network', 'infrastructur', 'test']
# ['devic', 'use', 'without', 'know', 'work', 'intern']
# ['devic', 'system', 'object', 'comput', 'view', 'term', 'input', 'output', 'without', 'requir', 'knowledg', 'intern', 'work']
# ['system', 'directli', 'observ', 'easili', 'undeestood']
# ['system', 'cannot', 'seen', 'understood', 'easili']
# ['penetr', 'test', 'penetr', 'test', 'tester', 'prior', 'knowledg', 'network', 'infrastructur', 'test']
# ['metaphor', 'process', 'action', 'produc', 'result', 'non', 'transpar', 'non', 'observ', 'manner', 'data', 'flow', 'diagram', 'process', 'appear', 'black', 'block', 'input', 'output', 'gener', 'function', 'process', 'known', 'underli', 'detail', 'shown']
# ['manipul', 'line', 'voltag', 'toll', 'free', 'call']
# ['type', 'tester', 'access', 'product', 'document', 'experi', 'applic']
# ['term', 'describ', 'situat', 'hidden', 'inner', 'object', 'process']
# ['system', 'cannot', 'directli', 'observ', 'easili', 'understood', 'see', 'work']
# ['analog', 'programm', 'use', 'refer', 'hidden', 'method', 'implement', 'detail']
# ['detail', 'softwar', 'work']
# ['goal', 'give', 'tester', 'inform', 'organ', 'network', 'configur', 'tester', 'act', 'hacker', 'discov', 'detail', 'detail', 'organ', 'configur', 'simul', 'attack']
# ['attack', 'knowledg', 'system']
# ['complex', 'system', 'cannot', 'directli', 'observ', 'easili', 'understood']
# ['tester', 'conduct', 'work', 'without', 'knowledg', 'target', 'environ']
# ['pen', 'tester', 'given', 'inform', 'organ', 'network', 'act', 'hacker', 'tri', 'get', 'sensit', 'inform', 'test', 'take', 'longest', 'simul', 'extern', 'attack']
# ['tester', 'provid', 'input', 'check', 'valid', 'output']
# ['devic', 'system', 'object', 'view', 'term', 'input', 'output', 'without', 'knowledg', 'intern', 'work', 'well', 'explain', 'interfac', 'ex', 'phone', 'tv', 'fridg']
# ['know', 'input', 'transform', 'output']
# ['type', 'penetr', 'test', 'tester', 'zero', 'knowledg', 'environ', 'prior', 'start', 'test']
# ['complet', 'seal', 'cannot', 'see', 'insid', 'input', 'output', 'test', 'knowledg', 'intern', 'aspect', 'test', 'mostli', 'ui', 'base']
# ['gener', 'term', 'unknown']
# ['base', 'function', 'specif', 'softwar', 'depend', 'specif', 'notat', 'use', 'scale', 'well', 'cannot', 'reveal', 'error', 'due', 'specif', 'code', 'given', 'function']
# ['statist', 'quantit', 'genet', 'trate', 'genom', 'provid', 'inform', 'individu', 'loci', 'rather', 'abstract', 'effect', 'gene', 'statist', 'paramet', 'varianc', 'covari', 'popul', 'level', 'vp', 'va', 'vd', 'vgxe', 'va', 'vd', 'genet', 'varianc', 'vg', 'known', 'herit', 'h2']
# ['intern', 'architectur', 'known', 'ever', 'test', 'noth', 'known', 'system']
# ['know', 'insid', 'know', 'work', 'run', 'program']
# ['system', 'cannot', 'directli', 'observ', 'easili', 'understood']
# ['metaphor', 'process', 'action', 'produc', 'result', 'non', 'transpar', 'non', 'observ', 'manner']
# ['inform', 'review', 'modul', 'code', 'complet', 'develop', 'team', 'decid', 'evalu', 'modul', 'end', 'user', 'perspect', 'method', 'use', 'determin', 'code', 'meet', 'qualiti', 'standard']
# ['repres', 'product', 'intern', 'compon', 'process']
# ['pen', 'tester', 'absolut', 'knowledg', 'system', 'function', 'manner', 'outsid', 'attack']
# ['function', 'test', 'strategi', 'input', 'gt', 'output', 'noth', 'see', 'code']
# ['flexibl', 'seat', 'arrang', 'seat', 'style']
# ['intern', 'process', 'cannot', 'seen', 'difficult', 'pre', 'determin']
# ['term', 'describ', 'mechan', 'accept', 'input', 'perform', 'oper', 'cannot', 'seen', 'input', 'produc', 'output']
# ['process', 'whose', 'oper', 'action', 'unknown', 'unspecifi']
# ['extern', 'look', 'test']
# ['test', 'without', 'knowledg', 'system', 'intern']
# ['devic', 'use', 'sole', 'term', 'input', 'output', 'regard', 'work']
# ['metaphor', 'process', 'action', 'produc', 'result', 'non', 'transpar', 'non', 'observ', 'manner', 'data', 'flow', 'diagram', 'process', 'appear', 'black', 'box', 'input', 'output', 'gener', 'function', 'process', 'known', 'underli', 'detail', 'shown']
# ['test', 'input', 'output', 'softwar', 'modul', 'test', 'without', 'examin', 'inner', 'work', 'softwar']
# ['test', 'tester', 'prior', 'knowledg', 'network', 'infrastructur', 'test']
# ['outsid', 'view', 'cant', 'see', 'code', 'partit', 'boundari', 'analysi']
# ['tester', 'knowledg', 'environ', 'like', 'attack']
# ['model', 'structur']
# ['aka', 'function', 'test', 'carri', 'independ', 'code', 'use', 'program', 'make', 'sure', 'program', 'function', 'specifi', 'requir']
# ['test', 'without', 'knowledg', 'code']
# ['term', 'firewal', 'stand', 'alon', 'softwar', 'instal', 'server', 'router', 'combin', 'hardwar', 'softwar']
# ['requir', 'penetr', 'tester', 'perform', 'reconnaiss']
# ['focu', 'evalu', 'research', 'whether', 'case', 'seem', 'chang', 'result', 'exposur', 'program', 'time', 'enter', 'program', 'input', 'exit', 'output']
# ['tester', 'prior', 'knowledg', 'network', 'infrastructur', 'test', 'close', 'mimic', 'attack', 'outsid', 'organ']
# ['theater', 'chang', 'move', 'provid', 'differ', 'act', 'space', 'stage']
# ['devic', 'use', 'without', 'understand', 'work']
# ['use', 'test', 'softwar', 'without', 'know', 'intern', 'structur', 'code', 'program']
# ['examin', 'function', 'applic', 'without', 'peer', 'intern', 'structur', 'work']
# ['user', 'test', 'function', 'user', 'input', 'valid', 'output', 'result', 'transit', 'boundari', 'case']
# ['test', 'method', 'conduct', 'assessor', 'inform', 'knowledg', 'inner', 'work', 'system', 'knowledg', 'sourc', 'code']
# ['anyth', 'cannot', 'observ', 'directli']
# ['phreak', 'tool', 'use', 'manipul', 'line', 'voltag', 'steal', 'long', 'distanc', 'servic']
# ['know', 'input', 'output', 'what', 'ex', 'comput']
# ['loos', 'coupl', 'compon', 'swap', 'anoth', 'one', 'neg', 'impact']
# ['tester', 'know', 'noth', 'network']
# ['organ', 'give', 'tester', 'inform', 'organ', 'network', 'infrastructur']
# ['inform', 'system', 'environ', 'perform', 'penetr', 'test']
# ['blind', 'test', 'pentest', 'know', 'noth', 'system']
# ['indic', 'potenti', 'life', 'threaten', 'condit']
# ['test', 'conduct', 'assessor', 'inform', 'knowledg', 'inner', 'work', 'system', 'knowledg', 'sourc', 'code']
# ['type', 'test', 'function', 'test']
# ['requir', 'verifi', 'usabl', 'product', 'deliv', 'ensur', 'overal', 'design', 'function', 'without', 'regard', 'intern', 'function', 'code', 'qualiti', 'method', 'meet', 'requir']
# ['prior', 'knowledg', 'system', 'network', 'assess']
# ['test', 'tester', 'knowledg', 'network', 'system', 'test']
# ['tester', 'given', 'littl', 'inform', 'target', 'like', 'real', 'world', 'time', 'consum', 'expens']
# ['knowledg', 'system', 'tester', 'oper', 'outsid', 'attack']
# ['intern', 'hidden', 'eg', '3rd', 'parti', 'librari', 'access', 'document', 'extern', 'interfac']
# ['term', 'use', 'indic', 'compon', 'comput', 'base', 'system', 'whih', 'user', 'need', 'know', 'detail', 'intern', 'oper']
# ['assessor', 'knowledg', 'inner', 'work', 'system', 'sourc', 'code']
# ['graphic', 'represent', 'system', 'object', 'design', 'input', 'shown', 'enter', 'left', 'output', 'leav', 'right']
# ['devic', 'method', 'use', 'without', 'know', 'work', 'intern']
# ['pen', 'tester', 'given', 'inform', 'organ', 'network', 'act', 'hacker', 'tri', 'get', 'sensit', 'inform', 'test', 'take', 'longest']
# ['toward', 'system', 'respond']
# ['system', 'structur', 'behavior', 'complet', 'understood']
# ['process', 'test', 'oper', 'action', 'unknown', 'unspecifi', 'test', 'featur', 'implement']
# ['system', 'cannot', 'directli', 'observ', 'easili', 'understood', 'unknown']
# ['new', 'applic', 'need', 'develop', 'use', 'exist', 'databas', 'applic', 'program', 'interfac', 'api', 'server', 'infrastructur', 'applic', 'creat', 'new', 'user', 'interfac', 'base', 'product', 'owner', 'graphic', 'user', 'interfac', 'gui', 'requir', 'test', 'method', 'verifi', 'function', 'gui', 'without', 'verifi', 'underli', 'code']
# ['definit', 'system', 'work', 'mysteri', 'cannot', 'see', 'insid', 'look', 'part', 'exampl', 'center', 'earth', 'like', 'black', 'box', 'never', 'see', 'insid']
# ['type', 'perform', 'space', 'small', 'creat', 'room', 'paint', 'black']
# ['robot', 'transfer', 'dna', 'extract', 'amplif', 'analysi']
# ['black', 'box', 'softwar', 'test', 'done', 'without', 'access', 'sourc', 'code', 'user', 'perspect', 'done', 'bug', 'identifi', 'detect', 'report', 'user', 'perspect', 'could', 'manual', 'autom', 'still', 'black', 'box']
# ['devic', 'use', 'without', 'regard', 'intern', 'mechan']
# ['system', 'cannot', 'seen', 'easili', 'understood']
# ['tester', 'zero', 'knowledg', 'environ', 'prior', 'start', 'test', 'instead', 'approach', 'test', 'knowledg', 'attack']
# ['process', 'symbol', 'data', 'flow', 'diagram']
# ['attack', 'knowledg', 'network', 'environ', 'extern', 'attack']
# ['definit', 'system', 'work', 'mysteri', 'cannot', 'see', 'insid', 'look', 'part', 'exampl', 'black', 'box', 'box', 'open', 'mysteri']
# ['tester', 'prior', 'knowledg', 'network', 'infrastructur', 'test']
# ['see', 'brain', 'activ', 'famili', 'chang', 'chang', 'rule', 'famili', 'need', 'insight', 'brain', 'activ', 'order', 'caus', 'chang', 'chang', 'systemat', 'rule', 'necessarili', 'consciou']
# ['test', 'softwar', 'extern', 'perspect', 'e', 'prior', 'knowledg', 'softwar', 'binari', 'execut', 'intermedi', 'byte', 'code', 'avail', 'analysi']
# ['flexibl', 'stage', 'theatr']
# ['occur', 'evalu', 'program', 'outcom', 'ignor', 'identifi', 'process', 'program', 'produc', 'effect']
# ['element', 'understood', 'person', 'use']
# ['analog', 'programm', 'use', 'refer', 'detail', 'hidden', 'method']
# ['orang', 'tail', 'seal']
# ['someth', 'easi', 'understand']
# ['tester', 'knowledg', 'environ', 'prior', 'start', 'test', 'approach', 'test', 'knowledg', 'attack', 'document', 'provid', 'use', 'fuzz', 'check', 'applic', 'vulner']
# ['compon', 'system', 'user', 'need', 'know', 'detail', 'intern', 'oper']
# ['pentest', 'know', 'noth', 'system', 'attack', 'blind']
# ['test', 'conduct', 'assessor', 'inform', 'knowledg', 'inner', 'work', 'system', 'knowledg', 'sourc', 'code', 'compar', 'grey', 'box', 'white', 'box']
# ['system', 'easili', 'observ']
# ['type', 'perform', 'space', 'small', 'creat', 'room']
# ['devic', 'system', 'object', 'view', 'term', 'input', 'output', 'transfer', 'characterist', 'without', 'knowledg', 'intern', 'work']
# ['process', 'requir', 'written', 'specifi', 'product', 'written', 'specif', 'requir']
# ['defin', 'requir', 'detail']
# ['activ', 'translat', 'inform', 'gather', 'requir', 'analysi', 'document', 'defin', 'set', 'requir', 'user', 'system', 'requir']
# ['collat', 'requir', 'requir', 'document']
# ['brief', 'statement', 'program', 'go']
# ['document', 'set', 'custom', 'requir', 'comput', 'system', 'written', 'part', 'system', 'analysi', 'use', 'later', 'evalu', 'system', 'implement']
# ['clear', 'list', 'function', 'non', 'function', 'requir', 'propos', 'project']
# ['restat', 'requir', 'specif', 'propos', 'system', 'shall', 'behav', 'aim', 'technic', 'audienc']
# ['restat', 'definit', 'technic', 'term', 'design', 'start', 'design']
# ['collect', 'engin', 'market', 'requir', 'system', 'must', 'satisfi', 'order', 'success']
# ['serv', 'contract', 'client', 'develop']
# ['client', 'involv', 'specif', 'client', 'sign', 'build', 'describ', 'buy', 'research', 'distinguish', 'requir', 'document', 'high', 'level', 'client', 'speak', 'requir', 'specif', 'low', 'level', 'design', 'speak', 'usual', 'use', 'standard', 'format', 'languag', 'aspect', 'might', 'specifi', 'use', 'logic']
# ['systemat', 'repres', 'collect', 'requir', 'typic', 'system', 'compon', 'satisfi', 'given', 'criteria', 'situat', 'distinguish', 'custom', 'requir', 'specif', 'typic', 'written', 'custom', 'system', 'requir', 'specif', 'softwar', 'requir', 'specif', 'written', 'supplier', 'requir', 'specif', 'may', 'also', 'denot', 'activ', 'specifi', 'requir']
# ['document', 'function', 'qualiti', 'constraint', 'softwar', 'use', 'formal', 'structur', 'notat', 'graphic', 'represent', 'ensur', 'clariti', 'consist', 'complet', 'popular', 'tool', 'uml', 'use', 'case', 'use', 'case', 'scenario', 'describ', 'end', 'user', 'interact', 'system', 'formal', 'sr', 'system', 'requir', 'specif', 'document', 'often', 'produc', 'typic', 'tradit', 'prescript', 'process']
# ['elicit', 'inform', 'work', 'domain', 'custom']
# ['tradit', 'approach', 'use', 'ieee', 'templat', 'upfront', 'detail', 'simpl', 'plain', 'languag', 'requir', 'statement', 'structur', 'use', 'case', 'next', 'week', 'lectur', 'agil', 'approach', 'use', 'subject', 'iter', 'user', 'stori', 'card', 'convers', 'confirm', 'user', 'stori', 'map', 'user', 'stori', 'estim', 'prioritis', 'user', 'stori', 'agil', 'card', 'wall']
# ['user', 'need', 'new', 'system']
# ['process', 'write', 'user', 'system', 'requir', 'requir', 'document']
# ['document', 'user', 'need', 'constraint', 'concis']
# ['rs', 'contain', 'gener', 'inform', 'system', 'set', 'requir', 'must', 'fulfil', 'rs', 'say', 'implement', 'inform']
# ['enumer', 'list', 'function', 'product', 'must', 'constraint', 'function', 'must', 'done']
# ['document', 'specifi', 'requir', 'format', 'better', 'suit', 'implement', 'signific', 'establish', 'agreement', 'basi', 'client', 'supplier', 'softwar', 'product', 'provid', 'refer', 'final', 'product', 'valid', 'high', 'qualiti', 'requir', 'specif', 'prerequisit', 'high', 'qualiti', 'softwar', 'reduc', 'develop', 'cost', 'avoid', 'behavior', 'guess', 'note', 'also', 'describ', 'softwar']
# ['activ', 'translat', 'inform', 'gather', 'analysi', 'activ', 'document', 'defin', 'set', 'requir']
# ['process', 'write', 'user', 'system', 'requir', 'requir', 'document', 'user', 'requir', 'understand', 'end', 'user', 'custom', 'technic', 'background', 'system', 'requir', 'detail', 'requir', 'may', 'includ', 'technic', 'inform']
# ['function', 'qualiti', 'constraint', 'system', 'document', 'form', 'use', 'case', 'user', 'stori', 'formal', 'mathemat', 'model', 'combin']
# ['requir', 'specif', 'activ', 'translat', 'inform', 'gather', 'analysi', 'activ', 'document', 'thatdefin', 'set', 'requir']
# ['design', 'custom', 'tri', 'captur', 'system', 'expect', 'provid', 'express', 'natur', 'languag', 'precis', 'languag', 'task', 'analysi', 'would', 'provid']
# ['process', 'gather', 'data', 'identifi', 'client', 'project', 'requir']
# ['document', 'system', 'requir', 'semiform', 'formal', 'manner', 'ensur', 'clariti', 'consist', 'complet']
# ['restat', 'requir', 'technic', 'format', 'action', 'develop']
# ['system', 'analyst', 'specifi', 'list', 'requir', 'new', 'system', 'requir', 'simpli', 'mean', 'target', 'aim']
# ['readabl', 'understand', 'non', 'ambigu', 'complet', 'verifi', 'consist', 'modifi', 'traceabl', 'usabl']
# ['descript', 'softwar', 'system', 'develop']
# ['repres', 'store', 'collect', 'requir', 'knowledg', 'persist', 'well', 'organ', 'fashion']
# ['process', 'formal', 'document', 'user', 'system', 'requir', 'creat', 'softwar', 'requir', 'document']
# ['written', 'natur', 'languag', 'structur', 'natur', 'languag', 'mathemat', 'specif', 'descript', 'languag', 'graphic', 'notat']
# ['specif', 'system', 'behav']
# ['defin', 'requir', 'detail']
# ['precis', 'descript', 'properti', 'behavior', 'someth', 'must']
# ['requir', 'written', 'intern', 'view', 'map', 'input', 'output']
# ['determin', 'document', 'detail', 'featur', 'function', 'desir', 'system', 'order', 'meet', 'organ', 'specif', 'goal']
# ['line', 'sku', 'close', 'relat']
# ['group', 'product', 'close', 'relat', 'function', 'similar', 'manner', 'sold', 'custom', 'group', 'market', 'type', 'outlet', 'fall', 'within', 'given', 'price', 'rang', 'eg', 'nike', 'produc', 'sever', 'line', 'athlet', 'shoe', 'apparel', 'marriott', 'offer', 'sever', 'line', 'hotel']
# ['creat', 'compani', 'market', 'strategi', 'captur', 'sale', 'consum', 'alreadi', 'buy', 'brand']
# ['firm', 'total', 'product', 'offer', 'design', 'satisfi', 'singl', 'need', 'desir', 'target', 'custom']
# ['line', 'stretch', 'fill', 'modern', 'featur', 'prune']
# ['group', 'product', 'close', 'relat', 'b', 'c', 'function', 'similar', 'manner', 'sold', 'custom', 'group', 'market', 'type', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['group', 'product', 'tht', 'close', 'relat', 'bc', 'function', 'similar', 'manner', 'sold', 'custom', 'group', 'market', 'type', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['singl', 'line', 'logic', 'diagram', 'use', 'repres', 'input', 'gate', 'pld', 'sum', 'product', 'array']
# ['group', 'product', 'close', 'relat']
# ['group', 'product', 'servic', 'satisfi', 'class', 'need']
# ['group', 'close', 'relat', 'product', 'item', 'bewar', 'cannib']
# ['sum', 'relat', 'individu', 'product', 'item']
# ['close', 'relat', 'product', 'similar', 'function', 'custom', 'group', 'solid', 'similar', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['group', 'close', 'relat', 'product', 'item']
# ['group', 'product', 'close', 'relat', 'function', 'similar', 'manner', 'sold', 'custom', 'group', 'line', 'van', 'shoe']
# ['group', 'close', 'relat', 'product', 'item', 'view', 'unit', 'market', 'technic', 'end', 'use', 'consider']
# ['group', 'similar', 'product', 'obviou', 'variat', 'design', 'qualiti', 'meet', 'need', 'distinct', 'custom', 'group']
# ['group', 'product', 'close', 'relat', 'satisfi', 'class', 'need', 'use', 'togeth', 'sold', 'custom', 'group', 'distribut', 'type', 'outlet', 'fall', 'within', 'given', 'price', 'rang', 'product', 'item', 'specif', 'product', 'note', 'uniqu', 'brand', 'size', 'price', 'size', 'consid', 'stock', 'keep', 'unit', 'sku', 'allow', 'simplif', 'busi', 'decis']
# ['group', 'similar', 'product', 'differ', 'rel', 'minor', 'characterist']
# ['group', 'close', 'relat', 'product', 'similar', 'function', 'custom', 'outlet', 'price']
# ['collect', 'product', 'item', 'close', 'relat', 'product', 'item', 'ex', 'expo', 'marker', 'wide', 'tip', 'pen', 'narrow', 'tip', 'clicker', 'laundri', 'deterg']
# ['group', 'product', 'servic', 'item', 'close', 'relat', 'satisfi', 'class', 'need', 'use', 'togeth', 'sold', 'custom', 'group', 'distribut', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['group', 'similar', 'product', 'made', 'sold', 'one', 'compani']
# ['close', 'relat', 'product', 'similar', 'function', 'custom', 'group', 'sold', 'similar', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['firm', 'total', 'product', 'offer', 'satisfi', 'similar', 'need', 'target', 'custom']
# ['activit', 'take', 'place', 'order', 'support', 'product', 'line', 'regardless', 'number', 'batch', 'individu', 'unit', 'actual', 'produc', 'e', 'engin', 'product', 'design', 'storag', 'special', 'warehous', 'manag', 'special', 'supervisor', 'activ', 'associ', 'particular', 'product', 'line', 'order', 'purchas', 'receiv', 'materi', 'uniqu', 'particular', 'product', 'line']
# ['group', 'product', 'link', 'usag', 'custom', 'profil', 'price', 'point', 'distribut', 'channel', 'need', 'satisfact']
# ['group', 'product', 'close', 'relat', 'function', 'similar', 'manner', 'sold', 'custom', 'group', 'market', 'type', 'outlet', 'fall', 'within', 'given', 'price', 'rang']
# ['group', 'close', 'relat', 'product', 'sold', 'compani', 'brand']
# ['group', 'product', 'compani', 'defin', 'similar', 'necessarili', 'brand']
# ['total', 'product', 'offer', 'design', 'satisfi', 'singl', 'need', 'desir']
# ['concern', 'control', 'distribut', 'data', 'collect', 'custom', 'supplier', 'employe']
# ['safeguard', 'person', 'data', 'collect', 'org', 'inappropriatli', 'access', 'use', 'org', 'collect', 'ensur', 'data', 'privaci', 'allow', 'individu', 'control', 'person', 'data', 'onlin', 'behavior', 'data', 'locat', 'data', 'financi', 'data', 'polit', 'data', 'medic', 'data']
# ['protect', 'privaci', 'data', 'locat', 'databas']
# ['compani', 'must', 'tell', 'individu', 'person', 'inform', 'protect', 'limit', 'place', 'data', 'share']
# ['need', 'preserv', 'protect', 'person', 'inform', 'collect', 'organ', 'access', 'third', 'parti']
# ['relationship', 'collect', 'dissemin', 'inform', 'public', 'expect', 'privaci']
# ['refer', 'data', 'collect', 'share', 'use', 'data', 'collect', 'consent', 'violat', 'data', 'privaci', 'make', 'sure', 'data', 'collect', 'correct', 'manner']
# ['role', 'may', 'monitor', 'complianc', 'hipaa', 'arra', 'law', 'work', 'other', 'assess', 'risk', 'custom', 'inform', 'develop', 'polici', 'procedur', 'requir', 'minim', 'risk', 'custom', 'inform']
# ['must', 'care', 'share', 'info']
# ['safeguard', 'person', 'data', 'collect', 'organ', 'inappropri', 'without', 'consent', 'access', 'use', 'organ', 'collect', 'data', 'third', 'parti', 'ensur', 'data', 'privaci', 'allow', 'individu', 'control', 'person', 'data']
# ['inform', 'protect', 'busi', 'respect', 'except', 'claim', 'privaci', 'polici']
# ['protect', 'privaci', 'data', 'locat', 'databas', 'page']
# ['make', 'sure', 'data', 'protect', 'unauthor', 'access']
# ['requir', 'data', 'avail', 'author', 'user']
# ['address', 'protect', 'privaci', 'person', 'data', 'store', 'databas']
# ['individu', 'right', 'keep', 'certain', 'inform', 'privat', 'inform', 'self', 'determin']
# ['keep', 'data', 'privat', 'view', 'owner', 'authoris', 'individu']
# ['safeguard', 'person', 'data', 'collect', 'organ', 'inappropri', 'without', 'consent', 'access', 'use', 'organ', 'collect', 'data', 'third', 'parti']
# ['ensur', 'data', 'avail', 'author', 'user']
# ['privaci', 'person', 'inform', 'like', 'name', 'signatur', 'address', 'telephon', 'number', 'date', 'birth', 'medic', 'record', 'bank', 'account', 'detail', 'commentari', 'opinion', 'person']
# ['aspect', 'inform', 'technolog', 'deal', 'abil', 'organ', 'individu', 'determin', 'data', 'comput', 'system', 'share', 'third', 'parti']
# ['ensur', 'employe', 'access', 'minimum', 'amount', 'data', 'necessari', 'complet', 'job']
# ['safeguard', 'person', 'data', 'collect', 'organ', 'inappropri', 'access', 'use', 'organ', 'collect', 'data', 'third', 'parti', 'ensur', 'data', 'privaci', 'allow', 'individu', 'control', 'person', 'data']
# ['abil', 'control', 'decid', 'person', 'inform', 'commun', 'other']
# ['branch', 'data', 'secur', 'concern', 'proper', 'handl', 'data', 'consent', 'notic', 'regulatori', 'oblig']
# ['requir', 'data', 'avail', 'authoris', 'user', 'keep', 'data', 'privat', 'rather', 'public', 'domain']
# ['safeguard', 'person', 'data', 'collect', 'organ', 'inappropri', 'access', 'use', 'organ', 'collect', 'data', 'third', 'parti']
# ['role', 'may', 'monitor', 'complianc', 'hipaa', 'arra', 'law', 'work', 'other', 'assess', 'risk', 'health', 'inform', 'develop', 'polici', 'procedur', 'requir', 'minim', 'risk', 'health', 'inform']
# ['data', 'privaci', 'collect', 'protect', 'distribut', 'inform', 'especi', 'peopl', 'organ', 'busi']
# ['aspect', 'deal', 'abil', 'organ', 'individu', 'determin', 'data', 'comput', 'system', 'share', 'third', 'parti']
# ['relationship', 'collect', 'dissemin', 'data', 'technolog', 'public', 'expect', 'privaci', 'legal', 'polit', 'issu', 'surround', 'right', 'peopl', 'choos', 'freeli', 'circumst', 'extent', 'reveal', 'attitud', 'behavior']
# ['protect', 'person', 'identifi', 'inform', 'otherwis', 'sensit', 'inform', 'undesir', 'disclosur']
# ['aspect', 'inform', 'technolog', 'deal', 'abil', 'organ', 'individu', 'determin', 'data', 'comput', 'system', 'share', 'third', 'parti', 'aka', 'inform', 'privaci']
# ['fee', 'sourc', 'code', 'publish', 'avail', 'public', 'anyon', 'modifi', 'copi', 'redistribut', 'without', 'fee']
# ['mean', 'sourc', 'code', 'publish', 'made', 'avail', 'public', 'enabl', 'anyon', 'copi', 'modifi', 'redistribut', 'without', 'pay', 'fee', 'apach', 'openoffic']
# ['free', 'softwar', 'avail', 'licens', 'copyright', 'restrict']
# ['copyright', 'holder', 'provid', 'right', 'studi', 'chang', 'distribut', 'softwar']
# ['give', 'consum', 'access', 'sourc', 'code', 'chang', 'eve', 'redistribut']
# ['softwar', 'avail', 'download', 'cost', 'exampl', 'success', 'social', 'network', 'softwar', 'use', 'develop', 'virtual', 'learn', 'commun']
# ['noncommerci', 'softwar', 'share', 'freeli', 'develop', 'collect', 'internet', 'oper', 'system']
# ['softwar', 'avail', 'free', 'charg', 'licens', 'copyright', 'restrict']
# ['program', 'made', 'sourc', 'code', 'made', 'avail', 'public']
# ['free', 'openli', 'avail', 'everyon', 'peopl', 'creat', 'open', 'sourc', 'product', 'publish', 'code', 'allow', 'other', 'use', 'modifi', 'usual', 'test', 'public', 'onlin', 'contributor']
# ['given', 'away', 'sourc', 'code', 'softwar', 'sourc', 'code', 'made', 'freeli', 'avali', 'user', 'may', 'legal', 'modifi', 'code', 'creat', 'spin', 'softwar', 'exampl', 'mozilla', 'firefox', 'linux', 'success', 'open', 'sourc', 'os', 'releas', 'hundr', 'linux', 'base', 'oss', 'develop', 'ubuntu', 'debian', 'android', 'popular', 'open', 'sourc', 'softwar', 'alway', 'support', 'strong', 'onlin', 'commun', 'user', 'activ', 'help', 'improv', 'softwar']
# ['softwar', 'develop', 'commun', 'programm', 'make', 'softwar', 'avail', 'download', 'use', 'cost']
# ['use', 'anyon']
# ['softwar', 'sourc', 'code', 'made', 'avail']
# ['softwar', 'sourc', 'code', 'freeli', 'publicli', 'avail']
# ['noncommerci', 'softwar', 'share', 'freeli', 'develop', 'collect', 'internet']
# ['softwar', 'result', 'voluntari', 'collabor', 'develop', 'creat', 'program', 'distribut', 'free', 'other']
# ['program', 'code', 'made', 'publicli', 'avail', 'free', 'copi', 'distribut', 'chang', 'without', 'stringent', 'copyright']
# ['obtain', 'softwar', 'free', 'may', 'enhanc', 'softwar', 'may', 'distribut', 'softwar', 'gnu', 'public', 'licens']
# ['softwar', 'sourc', 'code', 'anyon', 'inspect', 'modifi', 'enhanc']
# ['softwar', 'whose', 'code', 'provid', 'use', 'modif', 'redistribut']
# ['program', 'code', 'made', 'publicli', 'avail', 'free', 'copi', 'distribut', 'chang', 'without', 'stringent', 'copyright', 'protect', 'proprietari', 'softwar', 'product']
# ['sourc', 'code', 'made', 'readili', 'avail', 'user', 'edit', 'redistribut', 'still', 'licens', 'associ', 'applic', 'grant', 'user', 'permiss', 'use', 'applic', 'purpos', 'wish', 'licens', 'state', 'modif', 'made', 'avail', 'user', 'alongsid', 'origin', 'code', 'redistribut', 'without', 'charg']
# ['free', 'softwar', 'peopl', 'abl', 'make', 'chang']
# ['free', 'develop', 'commun', 'interest', 'ppl', 'firefox', 'android', 'mysql']
# ['free', 'softwar', 'design', 'talent', 'peopl', 'chang', 'anyon', 'get', 'limit', 'technic', 'support']
# ['program', 'given', 'free', 'sourc', 'code', 'program', 'given', 'well', 'make', 'anyon', 'modifi', 'program']
# ['strength', 'huge', 'user', 'base', 'access', 'novel', 'featur', 'higher', 'qualiti', 'code', 'mani', 'peopl', 'work', 'togeth', 'solv', 'problem', 'fix', 'bug', 'weak', 'good', 'privat', 'softwar', 'softwar', 'w', 'deadlin', 'tech', 'support', 'iffi', 'financi', 'compens']
# ['avail', 'free', 'user', 'modifi', 'copyright', 'licens', 'fee', 'use', 'open', 'standard']
# ['program', 'code', 'made', 'publicli', 'avail', 'free', 'copi', 'distribut', 'chang', 'without', 'stringent', 'copyright', 'protect', 'proprietari', 'softwar', 'product']
# ['oss', 'defin', 'comput', 'softwar', 'whihc', 'human', 'readabl', 'sourc', 'code', 'made', 'avail', 'copyright', 'licens', 'arrang', 'public', 'domain', 'meet', 'open', 'sourc', 'definit', 'permit', 'user', 'use', 'chang', 'improv', 'softwar', 'redistribut', 'modifi', 'unmodifi', 'form', 'develop', 'public', 'collabor', 'manner']
# ['edit', 'sourc', 'code', 'creativ', 'freedom']
# ['free', 'sourc', 'code', 'given', 'modifi', 'reus', 'distribut', 'copyleft', 'term', 'condit', 'meet', 'criteria']
# ['softwar', 'program', 'code', 'freeli', 'avail', 'modif', 'case', 'open', 'sourc', 'softwar', 'also', 'free', 'softwar']
# ['softwar', 'provid', 'use', 'modif', 'redistribut', 'restrict', 'copyright', 'holder', 'regard', 'modif', 'softwar', 'intern', 'instruct', 'redistribut']
# ['make', 'sourc', 'avail', 'public', 'softwar', 'improv', 'benefit', 'innov', 'user', 'wikipedia']
# ['sourc', 'code', 'avail', 'programm', 'want', 'modifi', 'improv', 'softwar']
# ['softwar', 'freeli', 'use', 'modifi', 'share']
# ['softwar', 'develop', 'commun', 'programm', 'design', 'free', 'use', 'modifi']
# ['softwar', 'develop', 'usual', 'unpaid', 'individu', 'volunt', 'basi', 'sourc', 'code', 'visibl', 'provid', 'free', 'cost']
# ['softwar', 'freeli', 'avail', 'sourc', 'code', 'also', 'avail']
# ['comput', 'softwar', 'code', 'made', 'avail', 'anyon', 'purpos', 'code', 'develop', 'group']
# ['softwar', 'develop', 'collabor', 'loos', 'knit', 'group', 'programm', 'agre', 'join', 'effort', 'improv', 'debug', 'softwar', 'product', 'sourc', 'code', 'program', 'usual', 'avail', 'without', 'cost']
# ['code', 'provid', 'use', 'modif', 'redistribut']
# ['distribut', 'free', 'sourc', 'code', 'chang', 'user', 'improv', 'fit', 'need', 'run', 'program', 'purpos', 'adapt', 'need', 'improv', 'made', 'must', 'releas', 'public', 'cannot', 'own', 'one', 'person', 'user', 'support', 'exampl', 'linux', 'mysql', 'firefox']
# ['softwar', 'avail', 'free', 'charg', 'licens', 'copyright', 'restrict', 'one', 'advantag', 'open', 'sourc', 'softwar', 'commun', 'passion', 'user', 'continu', 'make', 'chang', 'softwar', 'base', 'user', 'feedback', 'howev', 'unlik', 'proprietari', 'applic', 'open', 'sourc', 'applic', 'offer', 'littl', 'formal', 'support']
# ['softwar', 'free', 'avail', 'everyon', 'anyon', 'modifi']
# ['sourc', 'code', 'avail', 'public', 'chang', 'use', 'wish', 'work', 'share', 'develop', 'commun', 'often', 'free', 'charg']
# ['softwar', 'develop', 'commun', 'programm', 'design', 'free', 'use', 'modifi', 'pg']
# ['softwar', 'develop', 'programm', 'intent', 'make', 'free', 'use', 'applic']
# ['make', 'sourc', 'code', 'avail', 'modifi', 'improv']
# ['softwar', 'design', 'access', 'public', 'includ', 'free', 'access', 'sourc', 'code', 'abil', 'modifi']
# ['typic', 'free', 'softwar', 'sourc', 'code', 'made', 'freeli', 'avail']
# ['noncommerci', 'softwar', 'share', 'freeli', 'develop', 'collect', 'internet', 'ex', 'linux', 'android']
# ['allow', 'user', 'access', 'modifi', 'softwar', 'sourc', 'code']
# ['collabor', 'free', 'labour', 'publicli', 'avail', 'volunt', 'work', 'free', 'open', 'sourc', 'project', 'free', 'softwar', 'run', 'internet']
# ['free', 'user', 'free', 'usag', 'licens']
# ['softwar', 'made', 'avail', 'sourc', 'code', 'form', 'cost', 'develop', 'distribut', 'w', 'licens', 'term', 'ensur', 'sourc', 'code', 'alway', 'avail', 'user', 'ex', 'mozilla', 'firefox', 'web', 'browser']
# ['sourc', 'code', 'made', 'freeli', 'avail', 'user', 'may', 'legal', 'modifi', 'sourc', 'code', 'creat', 'spin', 'softwar']
# ['softwar', 'free', 'use', 'underli', 'code', 'avail', 'anyon', 'want', 'add', 'examin']
# ['program', 'sourc', 'code', 'made', 'avail', 'gener', 'public']
# ['develop', 'commun', 'oss', 'project', 'volunt', 'develop', 'littl', 'commerci', 'interest', 'product']
# ['noncommerci', 'softwar', 'share', 'freeli', 'develop', 'collect', 'internet', 'chang', 'softwar', 'use', 'code', 'ex', 'libreoffic', 'firefox', 'apach', 'android', 'ubuntu']
# ['noncommerci', 'softwar', 'share', 'freeli', 'develop', 'collect', 'internet', 'anyon', 'copi', 'chang', 'distribut']
# ['softwar', 'conform', 'open', 'sourc', 'licens', 'therefor', 'open', 'sourc', 'softwar']
# ['make', 'code', 'avail', 'public', 'modif', 'develop']
# ['softwar', 'sourc', 'code', 'made', 'avail', 'public']
# ['softwar', 'free', 'anyon', 'look', 'modifi', 'code']
# ['program', 'sourc', 'code', 'made', 'avail', 'gener', 'public', 'linux', 'first', 'wide', 'use', 'open', 'sourc', 'softwar']
# ['softwar', 'develop', 'commun', 'programm', 'ad', 'design', 'free', 'use', 'modifi']
# ['free', 'use', 'restrict', 'copyright', 'provid', 'softwar']
# ['copyright', 'softwar', 'linux', 'typic', 'distribut', 'free', 'charg', 'custom']
# ['softwar', 'licens', 'use', 'charg', 'licens', 'open', 'sourc', 'softwar', 'must', 'distribut', 'sourc', 'code', 'anyon', 'modifi', 'develop', 'sell', 'softwar', 'creat', 'new', 'softwar', 'creat', 'open', 'sourc', 'softwar', 'must', 'also', 'open', 'peopl', 'read', 'code', 'edit']
# ['program', 'code', 'made', 'publicli', 'avail', 'free', 'copi', 'distribut', 'chang', 'without', 'stringent', 'copyright', 'protect', 'proprietari', 'softwar', 'product', 'make', 'money']
# ['freeli', 'avail', 'internet', 'charg', 'money', 'constant', 'updat', 'avail', 'may', 'thoroughli', 'test', 'proprietari', 'softwar', 'free', 'use', 'user', 'modifi', 'sourc', 'code', 'suit', 'need', 'may', 'appear', 'user', 'friendli', 'profession', 'proprietari', 'softwar']
# ['softwar', 'avail', 'free', 'charg', 'licens', 'copyright', 'agreement']
# ['freeli', 'avail', 'includ', 'sourc', 'code', 'develop', 'commun', 'interest', 'peopl', 'perform', 'function', 'commerci', 'softwar']
# ['openli', 'share', 'sourc', 'code', 'chang', 'redistribut', 'anyon', 'cost', 'effici', 'reliabl', 'secur', 'scalabl', 'handl', 'increas', 'workload', 'potenti', 'manag', 'increas', 'workload', 'agil', 'time', 'market', 'modern', 'tech', 'compani', 'would', 'exist', 'without']
# ['softwar', 'linux', 'includ', 'uncompil', 'sourc', 'code', 'modifi', 'distribut', 'programm']
# ['make', 'sourc', 'code', 'avail', 'public', 'softwar', 'improv', 'benefit', 'innov', 'user']
# ['softwar', 'program', 'made', 'sourc', 'code', 'made', 'avail', 'public']
# ['softwar', 'hat', 'distribut', 'free', 'access', 'permit', 'sourc', 'code', 'studi', 'chang', 'improv', 'softwar', 'profession']
# ['program', 'sourc', 'code', 'avail', 'gener', 'public', 'use', 'modif', 'origin', 'design', 'free', 'charg']
# ['softwar', 'includ', 'sourc', 'code', 'allow', 'programm', 'modifi', 'improv']
# ...
# ['percentag', 'chang', 'npv', 'result', 'given', 'chang', 'input', 'variabl']
# ['analysi', 'project', 'much', 'solut', 'may', 'chang', 'chang', 'variabl', 'input', 'data']
# ['use', 'determin', 'whether', 'differ', 'across', 'studi', 'may', 'explain', 'characterist', 'variou', 'popul', 'studi']
# ['calcul', 'effect', 'npv', 'irr', 'chang', 'unit', 'sale', 'sale', 'price', 'variabl', 'fix', 'cost', 'initi', 'invest', 'work', 'capit', 'etc']
# ['determin', 'solut', 'chang', 'base', 'upon', 'chang', 'mathemat', 'model', 'input', 'data']
# ['see', 'chang', 'one', 'input', 'variabl', 'impact', 'valu', 'one', 'outcom', 'variabl', 'excel', 'analysi', 'scenario', 'manag', 'data', 'tabl', 'goal', 'seek', 'analysi', 'solver']
# ['analysi', 'show', 'rang', 'possibl', 'outcom', 'specif', 'assumpt', 'chang']
# ['impact', 'key', 'assumpt', 'valuat', 'test', 'use', 'sensit', 'analysi']
# ['process', 'determin', 'sensit', 'optim', 'solut', 'chang', 'valu', 'use', 'equat']
# ['enabl', 'appli', 'differ', 'variabl', 'determin', 'variabl', 'determin', 'variabl', 'determin', 'maximum', 'price', 'could', 'pay', 'raw', 'materi', 'still', 'make', 'profit', 'determin', 'much', 'interest', 'rate', 'go', 'abl', 'afford', 'hous', 'monthli', 'payment']
# ['ask', 'seri', 'question', 'determin', 'show', 'optim', 'solut', 'chang', 'chang', 'one', 'assumpt', 'variabl', 'use', 'quantit', 'analysi']
# ['analysi', 'prokect', 'much', 'solut', 'may', 'chang', 'chang', 'vaariabl', 'unput', 'data']
# ['analyz', 'data', 'use', 'differ', 'popul', 'criteria', 'differ', 'statist', 'model', 'conduct', 'see', 'primari', 'analysi', 'result', 'robust', 'reliabl']
# ['determin', 'rang', 'probabl', 'altern', 'best', 'expect', 'payoff']
# ['techniqu', 'examin', 'optim', 'solut', 'linear', 'program', 'problem', 'chang', 'problem', 'data', 'modifi']
# ['studi', 'chang', 'coeffici', 'linear', 'program', 'problem', 'affect', 'optim', 'solut']
# ['assumpt', 'suitabl', 'model', 'may', 'question', 'exampl', 'happen', 'slope', 'rainfal', 'equal', 'import', 'popul', 'densiti', 'earlier', 'suitabl', 'model']
# ['test', 'conduct', 'show', 'much', 'total', 'profit', 'grow']
# ['techniqu', 'use', 'see', 'impact', 'chang', 'underli', 'variabl', 'answer']
# ['known', 'analysi', 'sensit', 'analysi', 'show', 'rang', 'possibl', 'outcom', 'specif', 'assumpt', 'chang', 'could', 'turn', 'influenc', 'financ', 'need', 'invest', 'fix', 'asset']
# ['use', 'determin', 'robust', 'given', 'altern', 'slight', 'chang', 'paramet', 'ideal', 'lead', 'slight', 'chang', 'altern', 'chosen']
# ['determin', 'much', 'result', 'chang', 'model', 'input', 'data', 'chang']
# ['analyz', 'sensitivw', 'determinist', 'solut', 'chang', 'assumpt', 'model']
# ['studi', 'chang', 'input', 'paramet', 'optim', 'model', 'affect', 'optim', 'situat', 'help', 'answer', 'question', 'chang', 'coeffici', 'certain', 'valu', 'constraint', 'affect', 'optim', 'solut', 'cant', 'one', 'unless', 'solut', 'optimal', 'solut', 'obtain']
# ['allow', 'us', 'measur', 'rel', 'influenc', 'attribut', 'output', 'result']
# ['percentag', 'chang', 'npv', 'result', 'given', 'percentag', 'chang', 'input', 'variabl', 'thing', 'held', 'constant']
# ['chang', 'input', 'impact', 'valu', 'outcom']
# ['studi', 'effect', 'chang', 'one', 'part', 'model', 'part', 'model', 'ex', 'chang', 'impact', 'model', 'excel']
# ['studi', 'impact', 'chang', 'one', 'part', 'model', 'part', 'model']
# ['chang', 'one', 'input', 'npv', 'examin', 'new', 'outcom', 'repeat', 'opposit', 'effect', 'much', 'outcom', 'chang', 'repeat', 'relev', 'input']
# ['studi', 'uncertainti', 'output', 'mathemat', 'model', 'system', 'numer', 'otherwis', 'apport', 'differ', 'sourc', 'uncertainti', 'input']
# ['question', 'real', 'world', 'situat', 'dynam', 'paramet', 'variabl', 'subject', 'chang']
# ['measur', 'effect', 'chang', 'variabl', 'project', 'npv', 'variabl', 'must', 'fix', 'expect', 'valu', 'besid', 'variabl', 'question']
# ['studi', 'meet', 'specif', 'criteria', 'remov', 'poor', 'qualiti', 'sensit', 'analysi', 'rerun', 'without', 'identifi', 'studi', 'determin', 'effect', 'individu', 'studi', 'overal', 'result']
# ['quantit', 'risk', 'analysi', 'model', 'techniqu', 'use', 'help', 'determin', 'risk', 'potenti', 'impact', 'project', 'examin', 'extent', 'uncertainti', 'project', 'element', 'affect', 'object', 'examin', 'uncertain', 'element', 'held', 'baselin', 'valu', 'typic', 'display', 'result', 'form', 'tornado', 'diagram', 'examin', 'effect', 'chang', 'three', 'area', 'contribut', 'rate', 'variabl', 'technolog', 'coeffici', 'number', 'constraint', 'equat', 'avail', 'resourc', 'right', 'hand', 'side', 'quantiti', 'constraint']
# ['analysi', 'techniqu', 'determin', 'individu', 'project', 'risk', 'sourc', 'uncertinti', 'potenti', 'impact', 'project', 'outcom', 'correl', 'variat', 'project', 'outcom', 'vairat', 'element', 'quantit', 'risk', 'analysi', 'model']
# ['studi', 'chang', 'input', 'paramet', 'optim', 'model', 'affect', 'optim', 'solut', 'help', 'answer', 'question', 'chang', 'coeffici', 'object', 'function', 'affect', 'optim', 'solut', 'chang', 'right', 'hand', 'side', 'valu', 'constraint', 'affect', 'optim', 'solut', 'sensit', 'analysi', 'concern', 'chang', 'affect', 'optim', 'solut', 'analysi', 'begin', 'optim', 'solut', 'origin', 'linear', 'program', 'problem', 'obtain']
# ['process', 'involv', 'determin', 'sensit', 'solut', 'chang', 'formul', 'problem']
# ['determin', 'sensit', 'solut', 'chang', 'valu', 'use', 'equat']
# ['use', 'evalu', 'risk', 'associ', 'given', 'invest', 'assess', 'impact', 'differ', 'variabl', 'invest', 'return', 'chang', 'variabl']
# ['determin', 'much', 'solut', 'chang', 'chang', 'model', 'input', 'data', 'postoptim', 'analysi']
# ['examin', 'sensit', 'output', 'chang', 'input', 'keep', 'input', 'constant']
# ['conduct', 'test', 'degre', 'total', 'profit', 'grow', 'shrink']
# ['base', 'question', 'effect', 'net', 'incom', 'sale', 'increas', 'rather', 'estim']
# ['studi', 'effect', 'chang', 'one', 'part', 'model', 'part', 'model']
# ['much', 'would', 'optim', 'valu', 'object', 'function', 'chang', 'per', 'one', 'unit', 'increas', 'right', 'hand', 'side', 'constraint', 'keep', 'factor', 'rang', 'chang', 'valid', 'bind', 'v', 'nonbind', 'constraint']
# ['techniqu', 'systemat', 'chang', 'paramet', 'model', 'determin', 'effect', 'chang']
# ['see', 'chang', 'one', 'input', 'variabl', 'impact', 'valu', 'one', 'outcom', 'variabl']
# ['impact', 'chang', 'one', 'part', 'decis', 'make', 'model', 'partt']
# ['much', 'iv', 'affect', 'dv', 'much', 'differ', 'dv', 'impact', 'decis']
# ['analyt', 'model', 'process', 'repeatedli', 'chang', 'singl', 'variabl', 'mathemat', 'model', 'see', 'variabl', 'affect']
# ['studi', 'impact', 'variabl', 'one', 'variabl', 'chang', 'repeatedli']
# ['attempt', 'assess', 'impact', 'chang', 'input', 'data', 'paramet', 'propos', 'solut', 'e', 'result', 'variabl']
# ['show', 'result', 'chang', 'specif', 'factor', 'exampl', 'impact', 'purchas', 'differ', 'group', 'increas', 'price']
# ['studi', 'effect', 'chang', 'one', 'input', 'variabl', 'propos', 'solut']
# ['use', 'analyz', 'chang', 'model', 'paramet']
# ['process', 'compar', 'model', 'secondari', 'model']
# ['understand', 'chang', 'analysi', 'outcom', 'base', 'assumpt', 'incorrect', 'modifi', 'one', 'input', 'e', 'g', 'develop', 'cost', 'examin', 'new', 'npv', 'outcom', 'compar', 'base', 'npv', 'outcom', 'repeat', 'opposit', 'modif', 'input', 'repeat', 'relev', 'input']
# ['sensit', 'result', 'paramet', 'chang']
# ['ask', 'seri', 'question', 'determin', 'optim', 'solut', 'chang', 'chang', 'one', 'assumpt', 'variabl', 'increas', 'variabl', 'unit', 'find', 'new', 'optim', 'result', 'percentag', 'increas', 'profit', 'calcul', 'find', 'sensit', 'variabl']
# ['studi', 'sensit', 'optim', 'solut', 'model', 'assumpt', 'data', 'chang', 'often', 'refer', 'post', 'optim', 'analysi']
# ['analysi', 'techniqu', 'determin', 'individu', 'project', 'risk', 'sourc', 'uncertainti', 'potenti', 'impact', 'project', 'outcom', 'correl', 'variat', 'project', 'outcom', 'variat', 'element', 'quantit', 'risk', 'analysi', 'model']
# ['measur', 'impact', 'chang', 'one', 'assumpt']
# ['scrutin', 'impact', 'chang', 'valu', 'referenc', 'formula', 'cell']
# ['understand', 'chang', 'analysi', 'outcom', 'case', 'assumpt', 'incorrect']
# ['chip', 'manag', 'access', 'ram', 'other', 'comm', 'directli', 'processor']
# ['chip', 'manag', 'access', 'ram']
# ['handl', 'dram', 'access', 'convert', 'request', 'processor', 'command', 'dram', 'exampl', 'load', '0xffff0000', 'may', 'becom', 'select', 'bank', 'x', 'row', 'access', 'column', 'read', 'x', 'precharg', 'must', 'also', 'arrang', 'command', 'order', 'time', 'taken', 'execut', 'minimis', 'sinc', 'take', 'differ', 'length', 'time', 'depend', 'whilst', 'respect', 'time', 'constraint', 'impos', 'dram', 'technolog', 'e', 'g', 'time', 'take', 'signal', 'propag', 'across', 'wire']
# ['improv', 'perform', 'processor', 'includ', 'memori', 'control', 'processor', 'die', 'rather', 'northbridg', 'chip', 'result', 'faster', 'memori', 'access', 'processor']
#                      entity     id  \
# 0        bottom-up approach      0
# 1        bottom-up approach      1
# 2        bottom-up approach      2
# 3        bottom-up approach      3
# 4        bottom-up approach      4
# ...                     ...    ...
# 30912  sensitivity analysis  30912
# 30913     memory controller  30913
# 30914     memory controller  30914
# 30915     memory controller  30915
# 30916     memory controller  30916
#
#                                               definition  \
# 0      estimates of duration and cost are made for ea...
# 1      pattern from process  deductive approach  use ...
# 2                                   normalization; 3nf\n
# 3                             client factor standpoint\n
# 4      approach for dynamic programming problems, whi...
# ...                                                  ...
# 30912  understand changes in the analysis outcome if ...
# 30913  the chip that manages access to the ram and a ...
# 30914                 chip that manages access to ram.\n
# 30915  this handles dram accesses by converting reque...
# 30916  to improve performance, some processors includ...
#
#                                                   tokens  \
# 0      [estim, durat, cost, made, compon, separ, comb...
# 1      [pattern, process, deduct, approach, use, unde...
# 2                                          [normal, 3nf]
# 3                           [client, factor, standpoint]
# 4      [approach, dynam, program, problem, problem, s...
# ...                                                  ...
# 30912  [understand, chang, analysi, outcom, case, ass...
# 30913  [chip, manag, access, ram, other, comm, direct...
# 30914                         [chip, manag, access, ram]
# 30915  [handl, dram, access, convert, request, proces...
# 30916  [improv, perform, processor, includ, memori, c...
#
#                                    max_pooling_embedding  \
# 0      [1.6786679029464722, 1.5756455659866333, 6.669...
# 1      [5.954471588134766, 2.4786300659179688, 2.4872...
# 2      [3.3570172786712646, 0.0, 1.9689255952835083, ...
# 3      [3.3282482624053955, 0.5294300317764282, 0.971...
# 4      [1.5540236234664917, 0.0, 3.4091858863830566, ...
# ...                                                  ...
# 30912  [4.280294418334961, 0.022109635174274445, 2.57...
# 30913  [4.733766078948975, 3.496218681335449, 3.64465...
# 30914  [0.0, 2.3875834941864014, 3.6446595191955566, ...
# 30915  [9.151537895202637, 7.432768821716309, 8.33754...
# 30916  [2.28523325920105, 2.3875834941864014, 4.38599...
#
#                                    min_pooling_embedding  \
# 0      [-1.1568663120269775, -4.001165866851807, -1.9...
# 1      [-1.6020854711532593, -8.456828117370605, -1.7...
# 2      [0.0, -0.34316229820251465, 0.0, 0.0, 0.0, 0.0...
# 3      [-1.0139529705047607, -1.449976921081543, -2.8...
# 4      [-4.258579254150391, -5.072784900665283, -2.92...
# ...                                                  ...
# 30912  [-1.1831191778182983, -5.760196685791016, -1.0...
# 30913  [-4.841139316558838, -5.148653984069824, -5.63...
# 30914  [-4.841139316558838, -1.8792915344238281, -5.6...
# 30915  [-6.727926731109619, -5.148653984069824, -4.23...
# 30916  [-2.5828394889831543, -5.292214393615723, -5.2...
#
#                                    avg_pooling_embedding  \
# 0      [0.08707362283021211, -1.1707010015845298, 1.7...
# 1      [0.9007936220616102, -0.8057965405285359, 0.17...
# 2      [1.950080782175064, -0.2777104079723358, 1.916...
# 3      [0.7105877747138342, -0.7486754258473715, -0.5...
# 4      [-1.2708764157511971, -3.20437846400521, 0.014...
# ...                                                  ...
# 30912  [1.661587978047984, -2.772448811147894, 1.2598...
# 30913  [-0.1898236069828272, -0.025680669292341918, -...
# 30914  [-2.1461488604545593, 0.564283549785614, -0.87...
# 30915  [0.45393201150000095, -0.22090421944785005, -0...
# 30916  [-0.034290690906345844, -2.1148334657773376, -...
#
#                                    sum_pooling_embedding  \
# 0      [0.8707362283021212, -11.707010015845299, 17.4...
# 1      [18.015872441232204, -16.115930810570717, 3.55...
# 2      [3.900161564350128, -0.5554208159446716, 3.832...
# 3      [2.1317633241415024, -2.2460262775421143, -1.7...
# 4      [-13.979640573263168, -35.24816310405731, 0.16...
# ...                                                  ...
# 30912  [11.631115846335888, -19.40714167803526, 8.819...
# 30913  [-1.5185888558626175, -0.20544535433873534, -1...
# 30914  [-8.584595441818237, 2.257134199142456, -3.488...
# 30915  [23.60446459800005, -11.487019411288202, -9.74...
# 30916  [-0.5486510545015335, -33.8373354524374, -19.5...
#
#                        tf_idf_weighted_pooling_embedding  max_pooling_score  \
# 0      [3.9182003177702427, -24.176996111869812, 34.6...           0.679641
# 1      [34.25498013943434, -15.956364393234253, -1.82...           0.773321
# 2      [9.084224224090576, -1.457794964313507, 10.542...           0.430628
# 3      [5.053221046924591, -3.8104820251464844, -2.73...           0.320402
# 4      [-29.39676159620285, -74.54962289333344, -2.52...           0.620124
# ...                                                  ...                ...
# 30912  [23.913735181093216, -40.287494637072086, 18.4...           0.607334
# 30913  [-3.093780666589737, -0.8318992350250483, -32....           0.652578
# 30914  [-18.939855098724365, 3.819213330745697, -10.6...           0.613702
# 30915  [27.690755650401115, -34.910686533898115, -27....           0.661478
# 30916  [-0.33126500248908997, -82.39730903506279, -62...           0.667109
#
#        min_pooling_score  sum_pooling_score  tf_idf_weighted_pooling_score  \
# 0               0.670485           0.385186                      -0.362722
# 1               0.667227           0.441355                      -0.418230
# 2               0.435267           0.039069                      -0.061027
# 3               0.554570          -0.338807                       0.353212
# 4               0.709553           0.296569                      -0.319942
# ...                  ...                ...                            ...
# 30912           0.817563           0.228332                      -0.246967
# 30913           0.678437           0.211754                      -0.078216
# 30914           0.622675           0.330219                      -0.198130
# 30915           0.733340           0.070410                       0.030531
# 30916           0.726708           0.150347                      -0.031841
#
#        avg_pooling_score
# 0               0.385186
# 1               0.441355
# 2               0.039069
# 3              -0.338807
# 4               0.296569
# ...                  ...
# 30912           0.228332
# 30913           0.211754
# 30914           0.330219
# 30915           0.070410
# 30916           0.150347
#
# [30917 rows x 14 columns]

# %%
# define queries and create dataframe
queries = np.array(["relational database", "garbage collection", "retrieval model"])
query_df = pd.DataFrame(queries, columns = ["query"])

# %%
# parse queries
query_df = query_df.assign(tokens=parse(query_df['query'], 
                                                remove_stopwords=remove_stopwords, 
                                                use_stemming=use_stemming, 
                                                remove_otherNoise=remove_otherNoise))
query_df
# Out:
# None of pre-processing options = 6
# After removing stop words = 6
# After removing stop words + stemming = 6
# After removing stop words + stemming + removing other noise = 6
#                  query             tokens
# 0  relational database   [relat, databas]
# 1   garbage collection  [garbag, collect]
# 2      retrieval model   [retriev, model]

# %%
# add columns of different pooling approaches
query_df = query_df.assign(max_pooling_embedding=max_pooling_df(model, query_df))
query_df = query_df.assign(min_pooling_embedding=min_pooling_df(model, query_df))
query_df = query_df.assign(avg_pooling_embedding=avg_pooling_df(model, query_df))
query_df = query_df.assign(sum_pooling_embedding=sum_pooling_df(model, query_df))
query_df = query_df.assign(tf_idf_weighted_pooling_embedding=tf_idf_weighted_pooling_df(model, query_df, df_dict))
query_df
# Out:
# ['relat', 'databas']
# ['garbag', 'collect']
# ['retriev', 'model']
#                  query             tokens  \
# 0  relational database   [relat, databas]
# 1   garbage collection  [garbag, collect]
# 2      retrieval model   [retriev, model]
#
#                                max_pooling_embedding  \
# 0  [3.9872241020202637, 0.9915001392364502, 1.298...
# 1  [2.5483362674713135, 2.524824857711792, 0.6170...
# 2  [0.0, 3.0120248794555664, 2.4329323768615723, ...
#
#                                min_pooling_embedding  \
# 0  [0.0, -2.307264566421509, -0.20304089784622192...
# 1  [0.0, -0.19416363537311554, -0.380535244941711...
# 2  [-1.9308950901031494, -3.3003108501434326, 0.0...
#
#                                avg_pooling_embedding  \
# 0  [2.529714584350586, -0.6578822135925293, 0.547...
# 1  [1.5329232811927795, 1.1653306111693382, 0.118...
# 2  [-1.7664902806282043, -0.1441429853439331, 1.8...
#
#                                sum_pooling_embedding  \
# 0  [5.059429168701172, -1.3157644271850586, 1.094...
# 1  [3.065846562385559, 2.3306612223386765, 0.2365...
# 2  [-3.5329805612564087, -0.2882859706878662, 3.6...
#
#                    tf_idf_weighted_pooling_embedding
# 0  [-13.113665103912354, 3.8408167362213135, -3.0...
# 1  [-6.994352877140045, -6.560199096798897, -1.42...
# 2  [8.184017658233643, 2.5812721252441406, -8.060...

# %%
def cosine(vector_1, vector_2):
    return (normalize(vector_1[:,np.newaxis], axis=0).ravel() * normalize(vector_2[:,np.newaxis], axis=0).ravel()).sum()
    
def cal_cosine_scores(query_df, query_idx, documents_df, col_name):
    query_embedding = query_df[col_name][query_idx]
    return documents_df[col_name].apply(lambda v: cosine(query_embedding, v))

# %%
def precision_10(query_df, idx, results_df):
    query = query_df["query"][idx]
    count = 0
    for row in range(10):
        if results_df["entity"].iloc[row] == query:
            count += 1
    return count / 10

# %% [markdown]
# ## Max Pooling

# %%
for idx in range(3):
    # calculate and rank by max_pooling_score
    print("Query: %s" % query_df["query"][idx])
    documents_df = documents_df.assign(max_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'max_pooling_embedding'))
    max_pooling_sorted_results = documents_df.sort_values("max_pooling_score", ascending=False)
    
    print("Top 10 documents after calculating max pooling score:")
    display(HTML(max_pooling_sorted_results.head(10)[['entity', 'id', 'definition', 'tokens', 'max_pooling_score']].to_html()))
        
    max_pooling_precision_10 = precision_10(query_df, idx, max_pooling_sorted_results)
    print("Max pooling precision: %f \r\n\r\n" % max_pooling_precision_10)
# Out:
# Query: relational database
# Top 10 documents after calculating max pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>max_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>28290</th>
#       <td>relational database</td>
#       <td>28290</td>
#       <td>database that contains two or more tables of related information\n</td>
#       <td>[databas, contain, two, tabl, relat, inform]</td>
#       <td>0.981985</td>
#     </tr>
#     <tr>
#       <th>28177</th>
#       <td>relational database</td>
#       <td>28177</td>
#       <td>relational database schema with data\n</td>
#       <td>[relat, databas, schema, data]</td>
#       <td>0.980311</td>
#     </tr>
#     <tr>
#       <th>2129</th>
#       <td>data structure</td>
#       <td>2129</td>
#       <td>how to organize data (data are organized using relations).\n</td>
#       <td>[organ, data, data, organ, use, relat]</td>
#       <td>0.976495</td>
#     </tr>
#     <tr>
#       <th>4648</th>
#       <td>data warehouse</td>
#       <td>4648</td>
#       <td>-set of related databases  -hierarchy of data\n</td>
#       <td>[set, relat, databas, hierarchi, data]</td>
#       <td>0.970704</td>
#     </tr>
#     <tr>
#       <th>773</th>
#       <td>relational model</td>
#       <td>773</td>
#       <td>a table of data where the relation between the entities can be seen.\n</td>
#       <td>[tabl, data, relat, entiti, seen]</td>
#       <td>0.966453</td>
#     </tr>
#     <tr>
#       <th>10773</th>
#       <td>adjacency matrix</td>
#       <td>10773</td>
#       <td>a table containing 0 or 1 in each posistion\n</td>
#       <td>[tabl, contain, posist]</td>
#       <td>0.962811</td>
#     </tr>
#     <tr>
#       <th>19673</th>
#       <td>database schema</td>
#       <td>19673</td>
#       <td>set of schemas for the relations of a database\n</td>
#       <td>[set, schema, relat, databas]</td>
#       <td>0.962662</td>
#     </tr>
#     <tr>
#       <th>19701</th>
#       <td>database schema</td>
#       <td>19701</td>
#       <td>set of all relation schemas in the database\n</td>
#       <td>[set, relat, schema, databas]</td>
#       <td>0.962662</td>
#     </tr>
#     <tr>
#       <th>5148</th>
#       <td>relational databases</td>
#       <td>5148</td>
#       <td>organize data into 2-d tables\n</td>
#       <td>[organ, data, tabl]</td>
#       <td>0.961089</td>
#     </tr>
#     <tr>
#       <th>2138</th>
#       <td>data structure</td>
#       <td>2138</td>
#       <td>data organized into tables\n</td>
#       <td>[data, organ, tabl]</td>
#       <td>0.961089</td>
#     </tr>
#   </tbody>
# </table>
# Max pooling precision: 0.200000
#
#
# Query: garbage collection
# Top 10 documents after calculating max pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>max_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15732</th>
#       <td>data set</td>
#       <td>15732</td>
#       <td>information collected\n</td>
#       <td>[inform, collect]</td>
#       <td>0.973514</td>
#     </tr>
#     <tr>
#       <th>17402</th>
#       <td>data gathering</td>
#       <td>17402</td>
#       <td>collections of data is imperative.\n</td>
#       <td>[collect, data, imper]</td>
#       <td>0.970608</td>
#     </tr>
#     <tr>
#       <th>15725</th>
#       <td>data set</td>
#       <td>15725</td>
#       <td>is a collection of data.\n</td>
#       <td>[collect, data]</td>
#       <td>0.966789</td>
#     </tr>
#     <tr>
#       <th>8758</th>
#       <td>data collection</td>
#       <td>8758</td>
#       <td>the process by which data are collected\n</td>
#       <td>[process, data, collect]</td>
#       <td>0.966432</td>
#     </tr>
#     <tr>
#       <th>8802</th>
#       <td>data collection</td>
#       <td>8802</td>
#       <td>the processes by which data are collected\n</td>
#       <td>[process, data, collect]</td>
#       <td>0.966432</td>
#     </tr>
#     <tr>
#       <th>17405</th>
#       <td>data gathering</td>
#       <td>17405</td>
#       <td>process of collecting data.\n</td>
#       <td>[process, collect, data]</td>
#       <td>0.966432</td>
#     </tr>
#     <tr>
#       <th>15782</th>
#       <td>data set</td>
#       <td>15782</td>
#       <td>collection of information or data.\n</td>
#       <td>[collect, inform, data]</td>
#       <td>0.963831</td>
#     </tr>
#     <tr>
#       <th>12409</th>
#       <td>application domain</td>
#       <td>12409</td>
#       <td>purpose of the data collection\n</td>
#       <td>[purpos, data, collect]</td>
#       <td>0.959557</td>
#     </tr>
#     <tr>
#       <th>2606</th>
#       <td>raw data</td>
#       <td>2606</td>
#       <td>data that have been collected, but has not been processed for use\n</td>
#       <td>[data, collect, process, use]</td>
#       <td>0.956864</td>
#     </tr>
#     <tr>
#       <th>17410</th>
#       <td>data gathering</td>
#       <td>17410</td>
#       <td>the process of collecting facts and figures\n</td>
#       <td>[process, collect, fact, figur]</td>
#       <td>0.956461</td>
#     </tr>
#   </tbody>
# </table>
# Max pooling precision: 0.000000
#
#
# Query: retrieval model
# Top 10 documents after calculating max pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>max_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9085</th>
#       <td>query language</td>
#       <td>9085</td>
#       <td>used to update and retrieve data that is stored in a data model\n</td>
#       <td>[use, updat, retriev, data, store, data, model]</td>
#       <td>0.939912</td>
#     </tr>
#     <tr>
#       <th>9707</th>
#       <td>data mining</td>
#       <td>9707</td>
#       <td>a technique used to analyze and extract information from massive databases\n</td>
#       <td>[techniqu, use, analyz, extract, inform, massiv, databas]</td>
#       <td>0.915039</td>
#     </tr>
#     <tr>
#       <th>23571</th>
#       <td>knowledge workers</td>
#       <td>23571</td>
#       <td>-use technology to acquire and apply information\n</td>
#       <td>[use, technolog, acquir, appli, inform]</td>
#       <td>0.914696</td>
#     </tr>
#     <tr>
#       <th>19727</th>
#       <td>online analytical processing</td>
#       <td>19727</td>
#       <td>tools for retrieving, processing, and modelling data from the data warehouse\n</td>
#       <td>[tool, retriev, process, model, data, data, warehous]</td>
#       <td>0.907326</td>
#     </tr>
#     <tr>
#       <th>19708</th>
#       <td>online analytical processing</td>
#       <td>19708</td>
#       <td>olap - tools for retrieving, processing, and modeling data from the data warehouse\n</td>
#       <td>[olap, tool, retriev, process, model, data, data, warehous]</td>
#       <td>0.905630</td>
#     </tr>
#     <tr>
#       <th>6725</th>
#       <td>hot spots</td>
#       <td>6725</td>
#       <td>the hawaiian islands are made from what structures.\n</td>
#       <td>[hawaiian, island, made, structur]</td>
#       <td>0.902652</td>
#     </tr>
#     <tr>
#       <th>10638</th>
#       <td>information system</td>
#       <td>10638</td>
#       <td>a method of gathering, storing, and analyzing data for the purpose of making business decisions\n</td>
#       <td>[method, gather, store, analyz, data, purpos, make, busi, decis]</td>
#       <td>0.902096</td>
#     </tr>
#     <tr>
#       <th>27657</th>
#       <td>database system</td>
#       <td>27657</td>
#       <td>collectively, the database model, the dbms, and the database itself\n</td>
#       <td>[collect, databas, model, dbm, databas]</td>
#       <td>0.901114</td>
#     </tr>
#     <tr>
#       <th>4565</th>
#       <td>data warehouse</td>
#       <td>4565</td>
#       <td>logical collection of information gathered from many different databases that supports business analysis\n</td>
#       <td>[logic, collect, inform, gather, mani, differ, databas, support, busi, analysi]</td>
#       <td>0.897147</td>
#     </tr>
#     <tr>
#       <th>13256</th>
#       <td>data transformation</td>
#       <td>13256</td>
#       <td>transforms the data for storing it in the proper format or structure for the purposes of querying and analysis.\n</td>
#       <td>[transform, data, store, proper, format, structur, purpos, queri, analysi]</td>
#       <td>0.895686</td>
#     </tr>
#   </tbody>
# </table>
# Max pooling precision: 0.000000

# %% [markdown]
# ## Min Pooling

# %%
for idx in range(3):
    # calculate and rank by min_pooling_score
    print("Query: %s" % query_df["query"][idx])
    documents_df = documents_df.assign(min_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'min_pooling_embedding'))
    min_pooling_sorted_results = documents_df.sort_values("min_pooling_score", ascending=False)
    
    print("Top 10 documents after calculating min pooling score:")
    display(HTML(min_pooling_sorted_results.head(10)[['entity', 'id', 'definition', 'tokens', 'min_pooling_score']].to_html()))
        
    min_pooling_precision_10 = precision_10(query_df, idx, min_pooling_sorted_results)
    print("Min pooling precision: %f \r\n\r\n" % min_pooling_precision_10)
# Out:
# Query: relational database
# Top 10 documents after calculating min pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>min_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4613</th>
#       <td>data warehouse</td>
#       <td>4613</td>
#       <td>a collection of databases\n</td>
#       <td>[collect, databas]</td>
#       <td>0.999127</td>
#     </tr>
#     <tr>
#       <th>4501</th>
#       <td>data warehouse</td>
#       <td>4501</td>
#       <td>a collection of organized databases\n</td>
#       <td>[collect, organ, databas]</td>
#       <td>0.991413</td>
#     </tr>
#     <tr>
#       <th>7097</th>
#       <td>data model</td>
#       <td>7097</td>
#       <td>the structure of a database.\n</td>
#       <td>[structur, databas]</td>
#       <td>0.989016</td>
#     </tr>
#     <tr>
#       <th>19641</th>
#       <td>database schema</td>
#       <td>19641</td>
#       <td>structure of a database\n</td>
#       <td>[structur, databas]</td>
#       <td>0.989016</td>
#     </tr>
#     <tr>
#       <th>11840</th>
#       <td>data warehousing</td>
#       <td>11840</td>
#       <td>collection of multiple databases\n</td>
#       <td>[collect, multipl, databas]</td>
#       <td>0.986152</td>
#     </tr>
#     <tr>
#       <th>27689</th>
#       <td>database system</td>
#       <td>27689</td>
#       <td>database + dbms\n</td>
#       <td>[databas, dbm]</td>
#       <td>0.978514</td>
#     </tr>
#     <tr>
#       <th>486</th>
#       <td>database design</td>
#       <td>486</td>
#       <td>the actual structure of the database\n</td>
#       <td>[actual, structur, databas]</td>
#       <td>0.967048</td>
#     </tr>
#     <tr>
#       <th>19676</th>
#       <td>database schema</td>
#       <td>19676</td>
#       <td>the description of a database.\n</td>
#       <td>[descript, databas]</td>
#       <td>0.961531</td>
#     </tr>
#     <tr>
#       <th>27663</th>
#       <td>database system</td>
#       <td>27663</td>
#       <td>the combination of database and a dbms.\n</td>
#       <td>[combin, databas, dbm]</td>
#       <td>0.960101</td>
#     </tr>
#     <tr>
#       <th>19702</th>
#       <td>database schema</td>
#       <td>19702</td>
#       <td>the overall description of the database\n</td>
#       <td>[overal, descript, databas]</td>
#       <td>0.959386</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: garbage collection
# Top 10 documents after calculating min pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>min_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12680</th>
#       <td>data integrity</td>
#       <td>12680</td>
#       <td>when an organization has inconsistent duplicated data\n</td>
#       <td>[organ, inconsist, duplic, data]</td>
#       <td>0.948432</td>
#     </tr>
#     <tr>
#       <th>11816</th>
#       <td>data warehousing</td>
#       <td>11816</td>
#       <td>combines data from multiple databases and data sources\n</td>
#       <td>[combin, data, multipl, databas, data, sourc]</td>
#       <td>0.931623</td>
#     </tr>
#     <tr>
#       <th>15116</th>
#       <td>data acquisition</td>
#       <td>15116</td>
#       <td>obtaining, cleaning, organizing, relating, and cataloging source data\n</td>
#       <td>[obtain, clean, organ, relat, catalog, sourc, data]</td>
#       <td>0.930939</td>
#     </tr>
#     <tr>
#       <th>4064</th>
#       <td>data extraction</td>
#       <td>4064</td>
#       <td>get data from multiple heterogeneous external sources\n</td>
#       <td>[get, data, multipl, heterogen, extern, sourc]</td>
#       <td>0.930898</td>
#     </tr>
#     <tr>
#       <th>5093</th>
#       <td>relational databases</td>
#       <td>5093</td>
#       <td>organize data into 2-d-rdms\n</td>
#       <td>[organ, data, rdm]</td>
#       <td>0.930323</td>
#     </tr>
#     <tr>
#       <th>2597</th>
#       <td>raw data</td>
#       <td>2597</td>
#       <td>data tha is not organized\n</td>
#       <td>[data, tha, organ]</td>
#       <td>0.929264</td>
#     </tr>
#     <tr>
#       <th>15729</th>
#       <td>data set</td>
#       <td>15729</td>
#       <td>an organized collection of data.\n</td>
#       <td>[organ, collect, data]</td>
#       <td>0.928937</td>
#     </tr>
#     <tr>
#       <th>2549</th>
#       <td>raw data</td>
#       <td>2549</td>
#       <td>data that is not organized\n</td>
#       <td>[data, organ]</td>
#       <td>0.928937</td>
#     </tr>
#     <tr>
#       <th>12559</th>
#       <td>data integrity</td>
#       <td>12559</td>
#       <td>ensuring that all data in a database is complete\n</td>
#       <td>[ensur, data, databas, complet]</td>
#       <td>0.924772</td>
#     </tr>
#     <tr>
#       <th>7834</th>
#       <td>data integration</td>
#       <td>7834</td>
#       <td>integrate multiple sources of data\n</td>
#       <td>[integr, multipl, sourc, data]</td>
#       <td>0.923666</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: retrieval model
# Top 10 documents after calculating min pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>min_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7132</th>
#       <td>relational algebra</td>
#       <td>7132</td>
#       <td>a collection of operations that are used to retrieve data from relations\n</td>
#       <td>[collect, oper, use, retriev, data, relat]</td>
#       <td>0.959149</td>
#     </tr>
#     <tr>
#       <th>7117</th>
#       <td>relational algebra</td>
#       <td>7117</td>
#       <td>set of relational operations for retrieving data\n</td>
#       <td>[set, relat, oper, retriev, data]</td>
#       <td>0.956718</td>
#     </tr>
#     <tr>
#       <th>14759</th>
#       <td>quantitative analysis</td>
#       <td>14759</td>
#       <td>analysis using objective data\n</td>
#       <td>[analysi, use, object, data]</td>
#       <td>0.953796</td>
#     </tr>
#     <tr>
#       <th>9085</th>
#       <td>query language</td>
#       <td>9085</td>
#       <td>used to update and retrieve data that is stored in a data model\n</td>
#       <td>[use, updat, retriev, data, store, data, model]</td>
#       <td>0.942148</td>
#     </tr>
#     <tr>
#       <th>9064</th>
#       <td>query language</td>
#       <td>9064</td>
#       <td>the part of the dml that involves data retrieval\n</td>
#       <td>[part, dml, involv, data, retriev]</td>
#       <td>0.939803</td>
#     </tr>
#     <tr>
#       <th>27657</th>
#       <td>database system</td>
#       <td>27657</td>
#       <td>collectively, the database model, the dbms, and the database itself\n</td>
#       <td>[collect, databas, model, dbm, databas]</td>
#       <td>0.938249</td>
#     </tr>
#     <tr>
#       <th>27708</th>
#       <td>input data</td>
#       <td>27708</td>
#       <td>data that you enter into a database\n</td>
#       <td>[data, enter, databas]</td>
#       <td>0.933132</td>
#     </tr>
#     <tr>
#       <th>7242</th>
#       <td>deadlock detection</td>
#       <td>7242</td>
#       <td>the dbms periodically tests the database for deadlocks\n</td>
#       <td>[dbm, period, test, databas, deadlock]</td>
#       <td>0.933004</td>
#     </tr>
#     <tr>
#       <th>1619</th>
#       <td>design goals</td>
#       <td>1619</td>
#       <td>* all pertinent data must be in database  * no redundant data  * size of database must be reasonable  * relations should be such that queries are reasonable to state  * eliminate update and deletion anomalies\n</td>
#       <td>[pertin, data, must, databas, redund, data, size, databas, must, reason, relat, queri, reason, state, elimin, updat, delet, anomali]</td>
#       <td>0.932356</td>
#     </tr>
#     <tr>
#       <th>28227</th>
#       <td>relational database</td>
#       <td>28227</td>
#       <td>a database using the relational data model.\n</td>
#       <td>[databas, use, relat, data, model]</td>
#       <td>0.932212</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000

# %% [markdown]
# ## Average Pooling

# %%
for idx in range(3):
    # calculate and rank by avg_pooling_score
    print("Query: %s" % query_df["query"][idx])
    documents_df = documents_df.assign(avg_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'avg_pooling_embedding'))
    avg_pooling_sorted_results = documents_df.sort_values("avg_pooling_score", ascending=False)
    
    print("Top 10 documents after calculating average pooling score:")
    display(HTML(avg_pooling_sorted_results.head(10)[['entity', 'id', 'definition', 'tokens', 'avg_pooling_score']].to_html()))
        
    avg_pooling_precision_10 = precision_10(query_df, idx, avg_pooling_sorted_results)
    print("Min pooling precision: %f \r\n\r\n" % avg_pooling_precision_10)
# Out:
# Query: relational database
# Top 10 documents after calculating average pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>avg_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>28134</th>
#       <td>relational database</td>
#       <td>28134</td>
#       <td>a database including tables that are related to each other\n</td>
#       <td>[databas, includ, tabl, relat]</td>
#       <td>0.977955</td>
#     </tr>
#     <tr>
#       <th>28210</th>
#       <td>relational database</td>
#       <td>28210</td>
#       <td>a collection of related database tables\n</td>
#       <td>[collect, relat, databas, tabl]</td>
#       <td>0.970409</td>
#     </tr>
#     <tr>
#       <th>771</th>
#       <td>relational model</td>
#       <td>771</td>
#       <td>a database is a collection of relations or tables.\n</td>
#       <td>[databas, collect, relat, tabl]</td>
#       <td>0.970409</td>
#     </tr>
#     <tr>
#       <th>28177</th>
#       <td>relational database</td>
#       <td>28177</td>
#       <td>relational database schema with data\n</td>
#       <td>[relat, databas, schema, data]</td>
#       <td>0.966726</td>
#     </tr>
#     <tr>
#       <th>28242</th>
#       <td>relational database</td>
#       <td>28242</td>
#       <td>a database in which data is separated into tables of related records. in access, a database includes a collection of objects-tables, queries, reports, forms, and other objects\n</td>
#       <td>[databas, data, separ, tabl, relat, record, access, databas, includ, collect, object, tabl, queri, report, form, object]</td>
#       <td>0.965342</td>
#     </tr>
#     <tr>
#       <th>4648</th>
#       <td>data warehouse</td>
#       <td>4648</td>
#       <td>-set of related databases  -hierarchy of data\n</td>
#       <td>[set, relat, databas, hierarchi, data]</td>
#       <td>0.964128</td>
#     </tr>
#     <tr>
#       <th>19673</th>
#       <td>database schema</td>
#       <td>19673</td>
#       <td>set of schemas for the relations of a database\n</td>
#       <td>[set, schema, relat, databas]</td>
#       <td>0.961921</td>
#     </tr>
#     <tr>
#       <th>19701</th>
#       <td>database schema</td>
#       <td>19701</td>
#       <td>set of all relation schemas in the database\n</td>
#       <td>[set, relat, schema, databas]</td>
#       <td>0.961921</td>
#     </tr>
#     <tr>
#       <th>28164</th>
#       <td>relational database</td>
#       <td>28164</td>
#       <td>table-based organization for a database in which queries can be specified using relational database operators\n</td>
#       <td>[tabl, base, organ, databas, queri, specifi, use, relat, databas, oper]</td>
#       <td>0.960825</td>
#     </tr>
#     <tr>
#       <th>30329</th>
#       <td>database server</td>
#       <td>30329</td>
#       <td>database management system (dbms)  tables  relationships  metadata\n</td>
#       <td>[databas, manag, system, dbm, tabl, relationship, metadata]</td>
#       <td>0.959668</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.500000
#
#
# Query: garbage collection
# Top 10 documents after calculating average pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>avg_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>315</th>
#       <td>data privacy</td>
#       <td>315</td>
#       <td>- refers to how data is collected, shared and used - data collection against consent is a violation of data privacy - makes sure data is collected in the correct manner\n</td>
#       <td>[refer, data, collect, share, use, data, collect, consent, violat, data, privaci, make, sure, data, collect, correct, manner]</td>
#       <td>0.904959</td>
#     </tr>
#     <tr>
#       <th>2567</th>
#       <td>raw data</td>
#       <td>2567</td>
#       <td>is primary data, collected from the source, has not been processed for use\n</td>
#       <td>[primari, data, collect, sourc, process, use]</td>
#       <td>0.901490</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>data privacy</td>
#       <td>326</td>
#       <td>safeguarding personal data, collected by any organization, from being inappropriately (without consent) accessed and used by the organization that collected the data or by a third party\n</td>
#       <td>[safeguard, person, data, collect, organ, inappropri, without, consent, access, use, organ, collect, data, third, parti]</td>
#       <td>0.897495</td>
#     </tr>
#     <tr>
#       <th>17402</th>
#       <td>data gathering</td>
#       <td>17402</td>
#       <td>collections of data is imperative.\n</td>
#       <td>[collect, data, imper]</td>
#       <td>0.895451</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>data privacy</td>
#       <td>335</td>
#       <td>safeguarding personal data, collected by any organization, from being inappropriately accessed and used by the organization that collected the data or by a third party\n</td>
#       <td>[safeguard, person, data, collect, organ, inappropri, access, use, organ, collect, data, third, parti]</td>
#       <td>0.895270</td>
#     </tr>
#     <tr>
#       <th>15725</th>
#       <td>data set</td>
#       <td>15725</td>
#       <td>is a collection of data.\n</td>
#       <td>[collect, data]</td>
#       <td>0.892510</td>
#     </tr>
#     <tr>
#       <th>2550</th>
#       <td>raw data</td>
#       <td>2550</td>
#       <td>aka primary data; collected from the source and has not been processed for use; usually never published in scientific papers; normally subjected to processing your data by calculating the rate of reaction\n</td>
#       <td>[aka, primari, data, collect, sourc, process, use, usual, never, publish, scientif, paper, normal, subject, process, data, calcul, rate, reaction]</td>
#       <td>0.891304</td>
#     </tr>
#     <tr>
#       <th>4335</th>
#       <td>data warehouse</td>
#       <td>4335</td>
#       <td>a central aggregation of data (that can be distributed physically) that starts from an analysis of what data already exists &amp;  how it can be collected and later used.\n</td>
#       <td>[central, aggreg, data, distribut, physic, start, analysi, data, alreadi, exist, collect, later, use]</td>
#       <td>0.878652</td>
#     </tr>
#     <tr>
#       <th>2536</th>
#       <td>raw data</td>
#       <td>2536</td>
#       <td>the data collected for statisicsl studies are called\n</td>
#       <td>[data, collect, statisicsl, studi, call]</td>
#       <td>0.878312</td>
#     </tr>
#     <tr>
#       <th>13250</th>
#       <td>data storage</td>
#       <td>13250</td>
#       <td>once collected, data is further categorized and centralized.\n</td>
#       <td>[collect, data, categor, central]</td>
#       <td>0.876179</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: retrieval model
# Top 10 documents after calculating average pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>avg_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4490</th>
#       <td>data warehouse</td>
#       <td>4490</td>
#       <td>is a specialized database that stores data in a format optimized for decision suppor\n</td>
#       <td>[special, databas, store, data, format, optim, decis, suppor]</td>
#       <td>0.901824</td>
#     </tr>
#     <tr>
#       <th>4338</th>
#       <td>data warehouse</td>
#       <td>4338</td>
#       <td>specialized db that stores data in a format optimized for decision support\n</td>
#       <td>[special, db, store, data, format, optim, decis, support]</td>
#       <td>0.895641</td>
#     </tr>
#     <tr>
#       <th>15641</th>
#       <td>data cube</td>
#       <td>15641</td>
#       <td>the multidimensional data structure used to store and manipulate data in a multidimensional dbms.\n</td>
#       <td>[multidimension, data, structur, use, store, manipul, data, multidimension, dbm]</td>
#       <td>0.891614</td>
#     </tr>
#     <tr>
#       <th>13256</th>
#       <td>data transformation</td>
#       <td>13256</td>
#       <td>transforms the data for storing it in the proper format or structure for the purposes of querying and analysis.\n</td>
#       <td>[transform, data, store, proper, format, structur, purpos, queri, analysi]</td>
#       <td>0.890154</td>
#     </tr>
#     <tr>
#       <th>4370</th>
#       <td>data warehouse</td>
#       <td>4370</td>
#       <td>a specialized database that stores data in a format optimized for decision support\n</td>
#       <td>[special, databas, store, data, format, optim, decis, support]</td>
#       <td>0.889069</td>
#     </tr>
#     <tr>
#       <th>9061</th>
#       <td>query language</td>
#       <td>9061</td>
#       <td>you use a specialized language called structured query language to retrieve and manipulate information in a database.\n</td>
#       <td>[use, special, languag, call, structur, queri, languag, retriev, manipul, inform, databas]</td>
#       <td>0.883169</td>
#     </tr>
#     <tr>
#       <th>10109</th>
#       <td>data mining</td>
#       <td>10109</td>
#       <td>with structured data\n</td>
#       <td>[structur, data]</td>
#       <td>0.879140</td>
#     </tr>
#     <tr>
#       <th>19727</th>
#       <td>online analytical processing</td>
#       <td>19727</td>
#       <td>tools for retrieving, processing, and modelling data from the data warehouse\n</td>
#       <td>[tool, retriev, process, model, data, data, warehous]</td>
#       <td>0.878449</td>
#     </tr>
#     <tr>
#       <th>15633</th>
#       <td>data cube</td>
#       <td>15633</td>
#       <td>a special database used to store data in olap reporting.\n</td>
#       <td>[special, databas, use, store, data, olap, report]</td>
#       <td>0.877279</td>
#     </tr>
#     <tr>
#       <th>29082</th>
#       <td>data cubes</td>
#       <td>29082</td>
#       <td>special database used to store data in olap reporting\n</td>
#       <td>[special, databas, use, store, data, olap, report]</td>
#       <td>0.877279</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000

# %% [markdown]
# ## Sum Pooling

# %%
for idx in range(3):
    # calculate and rank by sum_pooling_score
    print("Query: %s" % query_df["query"][idx])
    documents_df = documents_df.assign(sum_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'sum_pooling_embedding'))
    sum_pooling_sorted_results = documents_df.sort_values("sum_pooling_score", ascending=False)
    
    print("Top 10 documents after calculating sum pooling score:")
    display(HTML(sum_pooling_sorted_results.head(10)[['entity', 'id', 'definition', 'tokens', 'sum_pooling_score']].to_html()))
        
    sum_pooling_precision_10 = precision_10(query_df, idx, sum_pooling_sorted_results)
    print("Min pooling precision: %f \r\n\r\n" % sum_pooling_precision_10)
# Out:
# Query: relational database
# Top 10 documents after calculating sum pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>sum_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>28134</th>
#       <td>relational database</td>
#       <td>28134</td>
#       <td>a database including tables that are related to each other\n</td>
#       <td>[databas, includ, tabl, relat]</td>
#       <td>0.977955</td>
#     </tr>
#     <tr>
#       <th>28210</th>
#       <td>relational database</td>
#       <td>28210</td>
#       <td>a collection of related database tables\n</td>
#       <td>[collect, relat, databas, tabl]</td>
#       <td>0.970409</td>
#     </tr>
#     <tr>
#       <th>771</th>
#       <td>relational model</td>
#       <td>771</td>
#       <td>a database is a collection of relations or tables.\n</td>
#       <td>[databas, collect, relat, tabl]</td>
#       <td>0.970409</td>
#     </tr>
#     <tr>
#       <th>28177</th>
#       <td>relational database</td>
#       <td>28177</td>
#       <td>relational database schema with data\n</td>
#       <td>[relat, databas, schema, data]</td>
#       <td>0.966726</td>
#     </tr>
#     <tr>
#       <th>28242</th>
#       <td>relational database</td>
#       <td>28242</td>
#       <td>a database in which data is separated into tables of related records. in access, a database includes a collection of objects-tables, queries, reports, forms, and other objects\n</td>
#       <td>[databas, data, separ, tabl, relat, record, access, databas, includ, collect, object, tabl, queri, report, form, object]</td>
#       <td>0.965342</td>
#     </tr>
#     <tr>
#       <th>4648</th>
#       <td>data warehouse</td>
#       <td>4648</td>
#       <td>-set of related databases  -hierarchy of data\n</td>
#       <td>[set, relat, databas, hierarchi, data]</td>
#       <td>0.964128</td>
#     </tr>
#     <tr>
#       <th>19673</th>
#       <td>database schema</td>
#       <td>19673</td>
#       <td>set of schemas for the relations of a database\n</td>
#       <td>[set, schema, relat, databas]</td>
#       <td>0.961921</td>
#     </tr>
#     <tr>
#       <th>19701</th>
#       <td>database schema</td>
#       <td>19701</td>
#       <td>set of all relation schemas in the database\n</td>
#       <td>[set, relat, schema, databas]</td>
#       <td>0.961921</td>
#     </tr>
#     <tr>
#       <th>28164</th>
#       <td>relational database</td>
#       <td>28164</td>
#       <td>table-based organization for a database in which queries can be specified using relational database operators\n</td>
#       <td>[tabl, base, organ, databas, queri, specifi, use, relat, databas, oper]</td>
#       <td>0.960825</td>
#     </tr>
#     <tr>
#       <th>30329</th>
#       <td>database server</td>
#       <td>30329</td>
#       <td>database management system (dbms)  tables  relationships  metadata\n</td>
#       <td>[databas, manag, system, dbm, tabl, relationship, metadata]</td>
#       <td>0.959668</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.500000
#
#
# Query: garbage collection
# Top 10 documents after calculating sum pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>sum_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>315</th>
#       <td>data privacy</td>
#       <td>315</td>
#       <td>- refers to how data is collected, shared and used - data collection against consent is a violation of data privacy - makes sure data is collected in the correct manner\n</td>
#       <td>[refer, data, collect, share, use, data, collect, consent, violat, data, privaci, make, sure, data, collect, correct, manner]</td>
#       <td>0.904959</td>
#     </tr>
#     <tr>
#       <th>2567</th>
#       <td>raw data</td>
#       <td>2567</td>
#       <td>is primary data, collected from the source, has not been processed for use\n</td>
#       <td>[primari, data, collect, sourc, process, use]</td>
#       <td>0.901490</td>
#     </tr>
#     <tr>
#       <th>326</th>
#       <td>data privacy</td>
#       <td>326</td>
#       <td>safeguarding personal data, collected by any organization, from being inappropriately (without consent) accessed and used by the organization that collected the data or by a third party\n</td>
#       <td>[safeguard, person, data, collect, organ, inappropri, without, consent, access, use, organ, collect, data, third, parti]</td>
#       <td>0.897495</td>
#     </tr>
#     <tr>
#       <th>17402</th>
#       <td>data gathering</td>
#       <td>17402</td>
#       <td>collections of data is imperative.\n</td>
#       <td>[collect, data, imper]</td>
#       <td>0.895451</td>
#     </tr>
#     <tr>
#       <th>335</th>
#       <td>data privacy</td>
#       <td>335</td>
#       <td>safeguarding personal data, collected by any organization, from being inappropriately accessed and used by the organization that collected the data or by a third party\n</td>
#       <td>[safeguard, person, data, collect, organ, inappropri, access, use, organ, collect, data, third, parti]</td>
#       <td>0.895270</td>
#     </tr>
#     <tr>
#       <th>15725</th>
#       <td>data set</td>
#       <td>15725</td>
#       <td>is a collection of data.\n</td>
#       <td>[collect, data]</td>
#       <td>0.892510</td>
#     </tr>
#     <tr>
#       <th>2550</th>
#       <td>raw data</td>
#       <td>2550</td>
#       <td>aka primary data; collected from the source and has not been processed for use; usually never published in scientific papers; normally subjected to processing your data by calculating the rate of reaction\n</td>
#       <td>[aka, primari, data, collect, sourc, process, use, usual, never, publish, scientif, paper, normal, subject, process, data, calcul, rate, reaction]</td>
#       <td>0.891304</td>
#     </tr>
#     <tr>
#       <th>4335</th>
#       <td>data warehouse</td>
#       <td>4335</td>
#       <td>a central aggregation of data (that can be distributed physically) that starts from an analysis of what data already exists &amp;  how it can be collected and later used.\n</td>
#       <td>[central, aggreg, data, distribut, physic, start, analysi, data, alreadi, exist, collect, later, use]</td>
#       <td>0.878652</td>
#     </tr>
#     <tr>
#       <th>2536</th>
#       <td>raw data</td>
#       <td>2536</td>
#       <td>the data collected for statisicsl studies are called\n</td>
#       <td>[data, collect, statisicsl, studi, call]</td>
#       <td>0.878312</td>
#     </tr>
#     <tr>
#       <th>13250</th>
#       <td>data storage</td>
#       <td>13250</td>
#       <td>once collected, data is further categorized and centralized.\n</td>
#       <td>[collect, data, categor, central]</td>
#       <td>0.876179</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: retrieval model
# Top 10 documents after calculating sum pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>sum_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4490</th>
#       <td>data warehouse</td>
#       <td>4490</td>
#       <td>is a specialized database that stores data in a format optimized for decision suppor\n</td>
#       <td>[special, databas, store, data, format, optim, decis, suppor]</td>
#       <td>0.901824</td>
#     </tr>
#     <tr>
#       <th>4338</th>
#       <td>data warehouse</td>
#       <td>4338</td>
#       <td>specialized db that stores data in a format optimized for decision support\n</td>
#       <td>[special, db, store, data, format, optim, decis, support]</td>
#       <td>0.895641</td>
#     </tr>
#     <tr>
#       <th>15641</th>
#       <td>data cube</td>
#       <td>15641</td>
#       <td>the multidimensional data structure used to store and manipulate data in a multidimensional dbms.\n</td>
#       <td>[multidimension, data, structur, use, store, manipul, data, multidimension, dbm]</td>
#       <td>0.891614</td>
#     </tr>
#     <tr>
#       <th>13256</th>
#       <td>data transformation</td>
#       <td>13256</td>
#       <td>transforms the data for storing it in the proper format or structure for the purposes of querying and analysis.\n</td>
#       <td>[transform, data, store, proper, format, structur, purpos, queri, analysi]</td>
#       <td>0.890154</td>
#     </tr>
#     <tr>
#       <th>4370</th>
#       <td>data warehouse</td>
#       <td>4370</td>
#       <td>a specialized database that stores data in a format optimized for decision support\n</td>
#       <td>[special, databas, store, data, format, optim, decis, support]</td>
#       <td>0.889069</td>
#     </tr>
#     <tr>
#       <th>9061</th>
#       <td>query language</td>
#       <td>9061</td>
#       <td>you use a specialized language called structured query language to retrieve and manipulate information in a database.\n</td>
#       <td>[use, special, languag, call, structur, queri, languag, retriev, manipul, inform, databas]</td>
#       <td>0.883169</td>
#     </tr>
#     <tr>
#       <th>10109</th>
#       <td>data mining</td>
#       <td>10109</td>
#       <td>with structured data\n</td>
#       <td>[structur, data]</td>
#       <td>0.879140</td>
#     </tr>
#     <tr>
#       <th>19727</th>
#       <td>online analytical processing</td>
#       <td>19727</td>
#       <td>tools for retrieving, processing, and modelling data from the data warehouse\n</td>
#       <td>[tool, retriev, process, model, data, data, warehous]</td>
#       <td>0.878449</td>
#     </tr>
#     <tr>
#       <th>15633</th>
#       <td>data cube</td>
#       <td>15633</td>
#       <td>a special database used to store data in olap reporting.\n</td>
#       <td>[special, databas, use, store, data, olap, report]</td>
#       <td>0.877279</td>
#     </tr>
#     <tr>
#       <th>29082</th>
#       <td>data cubes</td>
#       <td>29082</td>
#       <td>special database used to store data in olap reporting\n</td>
#       <td>[special, databas, use, store, data, olap, report]</td>
#       <td>0.877279</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000

# %% [markdown]
# ## TF-IDF Weighted Pooling

# %%
for idx in range(3):
    # calculate and rank by tf_idf_weighted_pooling_score
    print("Query: %s" % query_df["query"][idx])
    documents_df = documents_df.assign(tf_idf_weighted_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'tf_idf_weighted_pooling_embedding'))
    tf_idf_weighted_pooling_sorted_results = documents_df.sort_values("tf_idf_weighted_pooling_score", ascending=False)
    
    print("Top 10 documents after calculating TF-IDF weighted pooling score:")
    display(HTML(tf_idf_weighted_pooling_sorted_results.head(10)[['entity', 'id', 'definition', 'tokens', 'tf_idf_weighted_pooling_score']].to_html()))
        
    tf_idf_weighted_pooling_precision_10 = precision_10(query_df, idx, tf_idf_weighted_pooling_sorted_results)
    print("Min pooling precision: %f \r\n\r\n" % tf_idf_weighted_pooling_precision_10)
# Out:
# Query: relational database
# Top 10 documents after calculating TF-IDF weighted pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>tf_idf_weighted_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11208</th>
#       <td>current trends</td>
#       <td>11208</td>
#       <td>-imprisonment rate of black men has dropped more than 24% -imprisonment rate of black women has dropped over 50% -imprisonment rate of white women has risen by 53% -incarceration overall is declining -war on drugs shift from marijuana/crack to meth/opioid -white people declining socioeconomic prospects  -criminal justice reform\n</td>
#       <td>[imprison, rate, black, men, drop, imprison, rate, black, women, drop, imprison, rate, white, women, risen, incarcer, overal, declin, war, drug, shift, marijuana, crack, meth, opioid, white, peopl, declin, socioeconom, prospect, crimin, justic, reform]</td>
#       <td>0.770818</td>
#     </tr>
#     <tr>
#       <th>11206</th>
#       <td>current trends</td>
#       <td>11206</td>
#       <td>1. imprisonment rate dropped 24% black men  2. imprisonment rate of black women dropped over 50% 3. imprisonment rate of white women risen by 53% 4. incarceration overall declining  5. war on drugs shift from marijuana and crack to meth and opiod 6. white people declining socioeconomic prospects narrowing significantly  7. criminal justice reform first step act signed december of last year\n</td>
#       <td>[imprison, rate, drop, black, men, imprison, rate, black, women, drop, imprison, rate, white, women, risen, incarcer, overal, declin, war, drug, shift, marijuana, crack, meth, opiod, white, peopl, declin, socioeconom, prospect, narrow, significantli, crimin, justic, reform, first, step, act, sign, decemb, last, year]</td>
#       <td>0.759508</td>
#     </tr>
#     <tr>
#       <th>228</th>
#       <td>black box</td>
#       <td>228</td>
#       <td>orange! in the tail and sealed\n</td>
#       <td>[orang, tail, seal]</td>
#       <td>0.752008</td>
#     </tr>
#     <tr>
#       <th>6324</th>
#       <td>direct manipulation</td>
#       <td>6324</td>
#       <td>coined by shneiderman (1983) due to his fascination with computer games at the time\n</td>
#       <td>[coin, shneiderman, due, fascin, comput, game, time]</td>
#       <td>0.697502</td>
#     </tr>
#     <tr>
#       <th>11701</th>
#       <td>false positives</td>
#       <td>11701</td>
#       <td>lack of false positives are a red flag. false positives occur close to the threshold. patients faking hearing loss lack false responses\n</td>
#       <td>[lack, fals, posit, red, flag, fals, posit, occur, close, threshold, patient, fake, hear, loss, lack, fals, respons]</td>
#       <td>0.681711</td>
#     </tr>
#     <tr>
#       <th>2002</th>
#       <td>video games</td>
#       <td>2002</td>
#       <td>more addictive than drugs; less time with school, work, family, and friends; leads to obesity; lack of sleep; more harmful than tv; kids dropping out of school\n</td>
#       <td>[addict, drug, less, time, school, work, famili, friend, lead, obes, lack, sleep, harm, tv, kid, drop, school]</td>
#       <td>0.681457</td>
#     </tr>
#     <tr>
#       <th>11697</th>
#       <td>false positives</td>
#       <td>11697</td>
#       <td>- a lack of false positives is a red flag. - often, patients will indicate that a sound was heard, even if a sound was not presented (false positive) - false positives tend to occur close to threshold - patients attempting to fake a hearing loss tend to lack false responses because the sound is actually always easy for them to hear.\n</td>
#       <td>[lack, fals, posit, red, flag, often, patient, indic, sound, heard, even, sound, present, fals, posit, fals, posit, tend, occur, close, threshold, patient, attempt, fake, hear, loss, tend, lack, fals, respons, sound, actual, alway, easi, hear]</td>
#       <td>0.674480</td>
#     </tr>
#     <tr>
#       <th>684</th>
#       <td>false positive rate</td>
#       <td>684</td>
#       <td>fp / (fp + tn), false alarm rate\n</td>
#       <td>[fp, fp, tn, fals, alarm, rate]</td>
#       <td>0.673031</td>
#     </tr>
#     <tr>
#       <th>4236</th>
#       <td>comprehensive evaluation</td>
#       <td>4236</td>
#       <td>case history, otoscopy, speech reception threshold, air conduction pure tone threshold, word recognition testing, and bone conduction pure tone threshold\n</td>
#       <td>[case, histori, otoscopi, speech, recept, threshold, air, conduct, pure, tone, threshold, word, recognit, test, bone, conduct, pure, tone, threshold]</td>
#       <td>0.652922</td>
#     </tr>
#     <tr>
#       <th>11709</th>
#       <td>false positives</td>
#       <td>11709</td>
#       <td>often, patients will indicate that a sound was heard, even if a sound was not presented   tend to occur close to threshold, patients attempting to fake a hearing loss tend to lack because the sound is actually easy for them to hear\n</td>
#       <td>[often, patient, indic, sound, heard, even, sound, present, tend, occur, close, threshold, patient, attempt, fake, hear, loss, tend, lack, sound, actual, easi, hear]</td>
#       <td>0.651725</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: garbage collection
# Top 10 documents after calculating TF-IDF weighted pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>tf_idf_weighted_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>228</th>
#       <td>black box</td>
#       <td>228</td>
#       <td>orange! in the tail and sealed\n</td>
#       <td>[orang, tail, seal]</td>
#       <td>0.692132</td>
#     </tr>
#     <tr>
#       <th>9661</th>
#       <td>new technology</td>
#       <td>9661</td>
#       <td>1.machine gun 2 flame thrower 3.mustard gas 4.tanks 5.airplanes\n</td>
#       <td>[machin, gun, flame, thrower, mustard, ga, tank, airplan]</td>
#       <td>0.680664</td>
#     </tr>
#     <tr>
#       <th>16711</th>
#       <td>total cost</td>
#       <td>16711</td>
#       <td>(q/2) (h) + (d/q) s\n</td>
#       <td>[q, h, q]</td>
#       <td>0.640698</td>
#     </tr>
#     <tr>
#       <th>16737</th>
#       <td>total cost</td>
#       <td>16737</td>
#       <td>(q/2) h+(d/q) s\n</td>
#       <td>[q, h, q]</td>
#       <td>0.640698</td>
#     </tr>
#     <tr>
#       <th>14457</th>
#       <td>new technologies</td>
#       <td>14457</td>
#       <td>tanks, machine guns, poison gas and trench warfare\n</td>
#       <td>[tank, machin, gun, poison, ga, trench, warfar]</td>
#       <td>0.640505</td>
#     </tr>
#     <tr>
#       <th>24293</th>
#       <td>semantic analysis</td>
#       <td>24293</td>
#       <td>- &amp;"the dog is in the pen.&amp;" vs. &amp;"the ink is in the pen.&amp;" - &amp;"i put the plant in the window&amp;" vs. &amp;"ford put the plant in mexico&amp;"\n</td>
#       <td>[dog, pen, vs, ink, pen, put, plant, window, vs, ford, put, plant, mexico]</td>
#       <td>0.628617</td>
#     </tr>
#     <tr>
#       <th>24516</th>
#       <td>greedy algorithm</td>
#       <td>24516</td>
#       <td>dijkstra's, prim's, kruskal's\n</td>
#       <td>[dijkstra, prim, kruskal]</td>
#       <td>0.624458</td>
#     </tr>
#     <tr>
#       <th>8402</th>
#       <td>metric space</td>
#       <td>8402</td>
#       <td>a metric space is a pair (x, d) where x is a set and d:xxx-&amp;gt;r is a map satisfying the following properties: a. for x1, x2 in x, d(x1, x2)≥0 and d(x1, x2)=0 if and only if x1=x2 (positive definite) b. for any x1, x2 in x, we have d(x1, x2)=d(x2, x1) (symmetric) c. for any x1, x2, x3 in x, we have d(x1, x2)≤d(x1, x3)+d(x3, x2) (triangle inequality)\n</td>
#       <td>[metric, space, pair, x, x, set, xxx, gt, r, map, satisfi, follow, properti, x1, x2, x, x1, x2, x1, x2, x1, x2, posit, definit, b, x1, x2, x, x1, x2, x2, x1, symmetr, c, x1, x2, x3, x, x1, x2, x1, x3, x3, x2, triangl, inequ]</td>
#       <td>0.613814</td>
#     </tr>
#     <tr>
#       <th>4168</th>
#       <td>triangle inequality</td>
#       <td>4168</td>
#       <td>|z1 + z2| &amp;lt;= |z1| + |z2| |z1 + z2| &amp;gt;= ||z1| - |z2||\n</td>
#       <td>[z1, z2, lt, z1, z2, z1, z2, gt, z1, z2]</td>
#       <td>0.609520</td>
#     </tr>
#     <tr>
#       <th>29572</th>
#       <td>classification problem</td>
#       <td>29572</td>
#       <td>målet er å forutsjå ein class label, osm er eit valg fra ei predefinert liste med muligheter.  outputen blir sortert som classes. for eksempel dersom ein skal finne ut arten til ein plante, så blir arten (output) ein klasse.\n</td>
#       <td>[målet, er, å, forutsjå, ein, class, label, osm, er, eit, valg, fra, ei, predefinert, list, med, mulighet, outputen, blir, sortert, som, class, eksempel, dersom, ein, skal, finn, ut, arten, til, ein, plant, så, blir, arten, output, ein, klass]</td>
#       <td>0.607189</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000
#
#
# Query: retrieval model
# Top 10 documents after calculating TF-IDF weighted pooling score:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>entity</th>
#       <th>id</th>
#       <th>definition</th>
#       <th>tokens</th>
#       <th>tf_idf_weighted_pooling_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2002</th>
#       <td>video games</td>
#       <td>2002</td>
#       <td>more addictive than drugs; less time with school, work, family, and friends; leads to obesity; lack of sleep; more harmful than tv; kids dropping out of school\n</td>
#       <td>[addict, drug, less, time, school, work, famili, friend, lead, obes, lack, sleep, harm, tv, kid, drop, school]</td>
#       <td>0.761038</td>
#     </tr>
#     <tr>
#       <th>23522</th>
#       <td>peer-to-peer networks</td>
#       <td>23522</td>
#       <td>all computers have equal status\n</td>
#       <td>[comput, equal, statu]</td>
#       <td>0.692104</td>
#     </tr>
#     <tr>
#       <th>15589</th>
#       <td>service providers</td>
#       <td>15589</td>
#       <td>- regional authorities - counties - special districts - cities - schools -conservancies and friends groups  financed primarily by taxes with user fees as a supplement source of income\n</td>
#       <td>[region, author, counti, special, district, citi, school, conserv, friend, group, financ, primarili, tax, user, fee, supplement, sourc, incom]</td>
#       <td>0.676906</td>
#     </tr>
#     <tr>
#       <th>27628</th>
#       <td>categorical data</td>
#       <td>27628</td>
#       <td>gender, race, bmi, presence of disease (y/n)\n</td>
#       <td>[gender, race, bmi, presenc, diseas, n]</td>
#       <td>0.654540</td>
#     </tr>
#     <tr>
#       <th>11701</th>
#       <td>false positives</td>
#       <td>11701</td>
#       <td>lack of false positives are a red flag. false positives occur close to the threshold. patients faking hearing loss lack false responses\n</td>
#       <td>[lack, fals, posit, red, flag, fals, posit, occur, close, threshold, patient, fake, hear, loss, lack, fals, respons]</td>
#       <td>0.652843</td>
#     </tr>
#     <tr>
#       <th>11206</th>
#       <td>current trends</td>
#       <td>11206</td>
#       <td>1. imprisonment rate dropped 24% black men  2. imprisonment rate of black women dropped over 50% 3. imprisonment rate of white women risen by 53% 4. incarceration overall declining  5. war on drugs shift from marijuana and crack to meth and opiod 6. white people declining socioeconomic prospects narrowing significantly  7. criminal justice reform first step act signed december of last year\n</td>
#       <td>[imprison, rate, drop, black, men, imprison, rate, black, women, drop, imprison, rate, white, women, risen, incarcer, overal, declin, war, drug, shift, marijuana, crack, meth, opiod, white, peopl, declin, socioeconom, prospect, narrow, significantli, crimin, justic, reform, first, step, act, sign, decemb, last, year]</td>
#       <td>0.637839</td>
#     </tr>
#     <tr>
#       <th>11208</th>
#       <td>current trends</td>
#       <td>11208</td>
#       <td>-imprisonment rate of black men has dropped more than 24% -imprisonment rate of black women has dropped over 50% -imprisonment rate of white women has risen by 53% -incarceration overall is declining -war on drugs shift from marijuana/crack to meth/opioid -white people declining socioeconomic prospects  -criminal justice reform\n</td>
#       <td>[imprison, rate, black, men, drop, imprison, rate, black, women, drop, imprison, rate, white, women, risen, incarcer, overal, declin, war, drug, shift, marijuana, crack, meth, opioid, white, peopl, declin, socioeconom, prospect, crimin, justic, reform]</td>
#       <td>0.635282</td>
#     </tr>
#     <tr>
#       <th>5337</th>
#       <td>social welfare</td>
#       <td>5337</td>
#       <td>funded by taxes looks out for the poorest members of society\n</td>
#       <td>[fund, tax, look, poorest, member, societi]</td>
#       <td>0.629812</td>
#     </tr>
#     <tr>
#       <th>26160</th>
#       <td>broad spectrum</td>
#       <td>26160</td>
#       <td>kills a lot of bacteria\n</td>
#       <td>[kill, lot, bacteria]</td>
#       <td>0.626813</td>
#     </tr>
#     <tr>
#       <th>9371</th>
#       <td>social networks</td>
#       <td>9371</td>
#       <td>what we do -post opinions, gossip, pictures, &amp;"away from home&amp;" status  what they do  -new services with unexpected privacy settings\n</td>
#       <td>[post, opinion, gossip, pictur, away, home, statu, new, servic, unexpect, privaci, set]</td>
#       <td>0.619492</td>
#     </tr>
#   </tbody>
# </table>
# Min pooling precision: 0.000000

# %% [markdown]
# Try different aggregation methods and report the precision@10 for these queries:
# * query: relational database
# * query: garbage collection
# * query: retrieval model

# %% [markdown]
# ### Discussion
# Among these aggregation methods, which one is the best and which one is the worst?

# %% [markdown]
# We can find that the precision@10 of these methods are all not that good.
#
# For query "relational database", only `Max Pooling`, `Sum Pooling` and `Average Pooling` have hit some target documents. And the precision@10 are 0.2, 0.5 and 0.5 respectively. The other methods all don't have related hits.
#
# For the other two queries "garbage collection" and "retrieval model", all methods don't have related hits.
#
# To sum up, based on the above results, all the methods are not that good, but among these methods, `Sum Pooling` and `Average Pooling` are the best.

# %% [markdown]
# # Part 3: Query Expansion via Word Embeddings (30 points)
# Remember the hardest query "retrieval model" in homework 1? Because there is no document containing "retrieval model" in the dataset, you cannot retrieve any documents by Boolean matching. Now, it is the time of your "revenge" via query expansion.
#
# In this part, your job is to expand the original query like "retrieval model" by adding semantically similar words (e.g., "search"), which are selected from all tokens in the dataset.
#
# There are many ways to do so. For this part, we want you to calculate the cosine similarity between each of the original query tokens and the other tokens based on their word embeddings.
#
# First, please find the top 3 similar tokens for:
# * relational
# * database
# * garbage
# * collection
# * retrieval
# * model

# %%
from collections import defaultdict

# %%
# your code here
# get the vocabulary dataframe
vocabulary = np.array([k for k in df_dict.keys()])
vocabulary_df = pd.DataFrame(vocabulary, columns = ["parsed_term"])
vocabulary_df
# Out:
#      parsed_term
# 0           lift
# 1             ie
# 2      intersect
# 3     expirament
# 4       overwhel
# ...          ...
# 9649        till
# 9650     feeback
# 9651  likelihood
# 9652     stepwis
# 9653         pop
#
# [9654 rows x 1 columns]

# %%
# parse the six terms and create a dataframe
terms = np.array(["relational", "database", "garbage", "collection", "retrieval", "model"])
term_df = pd.DataFrame(terms, columns = ["term"])
term_df = term_df.assign(parsed_term=parse(term_df['term'], 
                                                remove_stopwords=remove_stopwords, 
                                                use_stemming=use_stemming, 
                                                remove_otherNoise=remove_otherNoise))
term_df
# Out:
# None of pre-processing options = 6
# After removing stop words = 6
# After removing stop words + stemming = 6
# After removing stop words + stemming + removing other noise = 6
#          term parsed_term
# 0  relational     [relat]
# 1    database   [databas]
# 2     garbage    [garbag]
# 3  collection   [collect]
# 4   retrieval   [retriev]
# 5       model     [model]

# %%
def find_similar_word(model, term, vocabulary_df, top_k):
    scored_vocabulary_df = vocabulary_df.assign(cos=vocabulary_df["parsed_term"].apply(lambda row: cosine(model.wv[term], model.wv[row])))
    return scored_vocabulary_df.sort_values("cos", ascending=False).head(top_k+1)

# %%
similar_word_dict = defaultdict(list)

for index, row in term_df.iterrows():
    term = row["term"]
    parsed_term = row["parsed_term"][0]
    similar_word_df = find_similar_word(model, parsed_term, vocabulary_df, 3)
    for i, r in similar_word_df.iterrows():
        if r["parsed_term"] != parsed_term:
            similar_word_dict[term].append(r["parsed_term"])
            
similar_word_dict
# Out:
# defaultdict(list,
#             {'relational': ['entiti', 'predefin', 'tabl'],
#              'database': ['dbm', 'data', 'structur'],
#              'garbage': ['collector', 'longer', 'reclaim'],
#              'collection': ['gather', 'organ', 'repositori'],
#              'retrieval': ['store', 'metadata', 'updat'],
#              'model': ['breakthrough', 'mathemat', 'conceptu']})

# %%
for key, value in similar_word_dict.items():
    print("Top 3 similar words for '%s': %s" % (key, value))
# Out:
# Top 3 similar words for 'relational': ['entiti', 'predefin', 'tabl']
# Top 3 similar words for 'database': ['dbm', 'data', 'structur']
# Top 3 similar words for 'garbage': ['collector', 'longer', 'reclaim']
# Top 3 similar words for 'collection': ['gather', 'organ', 'repositori']
# Top 3 similar words for 'retrieval': ['store', 'metadata', 'updat']
# Top 3 similar words for 'model': ['breakthrough', 'mathemat', 'conceptu']

# %% [markdown]
# Second, please add these similar tokens to the orignal query and redo the **vector space model** in part 2.
# * query: relational database
# * query: garbage collection
# * query: retrieval model

# %%
def recall_10(query_df, idx, results_df):
    query = query_df["query"][idx]
    count = 0
    
    # count related docs
    num_related_docs = results_df["entity"].apply(lambda entity: 1 if entity == query else 0).sum()
    
    for row in range(10):
        if results_df["entity"].iloc[row] == query:
            count += 1
    return count / num_related_docs

# %% [markdown]
# ## Report recall@10 before the query expansion:

# %%
# Report recall@10 before the query expansion
for idx in range(3):
    print("Query: %s" % query_df["query"][idx])
    max_pooling_recall_10 = recall_10(query_df, idx, max_pooling_sorted_results)
    print("Max pooling recall@10 before the query expansion: %f \r\n" % max_pooling_recall_10)
# Out:
# Query: relational database
# Max pooling recall@10 before the query expansion: 0.000000
#
# Query: garbage collection
# Max pooling recall@10 before the query expansion: 0.000000
#
# Query: retrieval model
# Max pooling recall@10 before the query expansion: 0.000000

# %%
for idx in range(3):
    print("Query: %s" % query_df["query"][idx])
    min_pooling_recall_10 = recall_10(query_df, idx, min_pooling_sorted_results)
    print("Min pooling recall@10 before the query expansion: %f \r\n" % min_pooling_recall_10)
# Out:
# Query: relational database
# Min pooling recall@10 before the query expansion: 0.003521
#
# Query: garbage collection
# Min pooling recall@10 before the query expansion: 0.000000
#
# Query: retrieval model
# Min pooling recall@10 before the query expansion: 0.000000

# %%
for idx in range(3):
    print("Query: %s" % query_df["query"][idx])
    avg_pooling_recall_10 = recall_10(query_df, idx, avg_pooling_sorted_results)
    print("Average pooling recall@10 before the query expansion: %f \r\n" % avg_pooling_recall_10)
# Out:
# Query: relational database
# Average pooling recall@10 before the query expansion: 0.000000
#
# Query: garbage collection
# Average pooling recall@10 before the query expansion: 0.000000
#
# Query: retrieval model
# Average pooling recall@10 before the query expansion: 0.000000

# %%
for idx in range(3):
    print("Query: %s" % query_df["query"][idx])
    sum_pooling_recall_10 = recall_10(query_df, idx, sum_pooling_sorted_results)
    print("Sum pooling recall@10 before the query expansion: %f \r\n" % sum_pooling_recall_10)
# Out:
# Query: relational database
# Sum pooling recall@10 before the query expansion: 0.000000
#
# Query: garbage collection
# Sum pooling recall@10 before the query expansion: 0.000000
#
# Query: retrieval model
# Sum pooling recall@10 before the query expansion: 0.000000

# %%
for idx in range(3):
    print("Query: %s" % query_df["query"][idx])
    tf_idf_weighted_pooling_recall_10 = recall_10(query_df, idx, tf_idf_weighted_pooling_sorted_results)
    print("TF-IDF weighted pooling recall@10 before the query expansion: %f \r\n" % tf_idf_weighted_pooling_recall_10)
# Out:
# Query: relational database
# TF-IDF weighted pooling recall@10 before the query expansion: 0.000000
#
# Query: garbage collection
# TF-IDF weighted pooling recall@10 before the query expansion: 0.000000
#
# Query: retrieval model
# TF-IDF weighted pooling recall@10 before the query expansion: 0.000000

# %% [markdown]
# ## Report recall@10 after the query expansion:

# %%
# add query expansions
query_df["tokens"][0].extend(similar_word_dict['relational'])
query_df["tokens"][0].extend(similar_word_dict['database'])
query_df["tokens"][1].extend(similar_word_dict['garbage'])
query_df["tokens"][1].extend(similar_word_dict['collection'])
query_df["tokens"][2].extend(similar_word_dict['retrieval'])
query_df["tokens"][2].extend(similar_word_dict['model'])
query_df[["query", "tokens"]]

# %%
for idx in range(3):
    # calculate and rank by max_pooling_score
    print("Query: %s" % query_df["query"][idx])

    documents_df = documents_df.assign(max_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'max_pooling_embedding'))
    max_pooling_sorted_results = documents_df.sort_values("max_pooling_score", ascending=False)
        
    max_pooling_recall_10 = recall_10(query_df, idx, max_pooling_sorted_results)
    print("Max pooling recall@10 after query expansion: %f \r\n\r\n" % max_pooling_recall_10)
# Out:
# Query: relational database
# Max pooling recall@10 after query expansion: 0.007042
#
#
# Query: garbage collection
# Max pooling recall@10 after query expansion: 0.000000
#
#
# Query: retrieval model
# Max pooling recall@10 after query expansion: 0.000000

# %%
for idx in range(3):
    # calculate and rank by max_pooling_score
    print("Query: %s" % query_df["query"][idx])

    documents_df = documents_df.assign(min_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'min_pooling_embedding'))
    min_pooling_sorted_results = documents_df.sort_values("min_pooling_score", ascending=False)
        
    min_pooling_recall_10 = recall_10(query_df, idx, min_pooling_sorted_results)
    print("Min pooling recall@10 after query expansion: %f \r\n\r\n" % min_pooling_recall_10)
# Out:
# Query: relational database
# Min pooling recall@10 after query expansion: 0.000000
#
#
# Query: garbage collection
# Min pooling recall@10 after query expansion: 0.000000
#
#
# Query: retrieval model
# Min pooling recall@10 after query expansion: 0.000000

# %%
for idx in range(3):
    # calculate and rank by avg_pooling_score
    print("Query: %s" % query_df["query"][idx])

    documents_df = documents_df.assign(avg_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'avg_pooling_embedding'))
    avg_pooling_sorted_results = documents_df.sort_values("avg_pooling_score", ascending=False)
        
    avg_pooling_recall_10 = recall_10(query_df, idx, avg_pooling_sorted_results)
    print("Average pooling recall@10 after query expansion: %f \r\n\r\n" % avg_pooling_recall_10)
# Out:
# Query: relational database
# Average pooling recall@10 after query expansion: 0.017606
#
#
# Query: garbage collection
# Average pooling recall@10 after query expansion: 0.000000
#
#
# Query: retrieval model
# Average pooling recall@10 after query expansion: 0.000000

# %%
for idx in range(3):
    # calculate and rank by sum_pooling_score
    print("Query: %s" % query_df["query"][idx])

    documents_df = documents_df.assign(sum_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'sum_pooling_embedding'))
    sum_pooling_sorted_results = documents_df.sort_values("sum_pooling_score", ascending=False)
        
    sum_pooling_recall_10 = recall_10(query_df, idx, sum_pooling_sorted_results)
    print("Sum pooling recall@10 after query expansion: %f \r\n\r\n" % sum_pooling_recall_10)
# Out:
# Query: relational database
# Sum pooling recall@10 after query expansion: 0.017606
#
#
# Query: garbage collection
# Sum pooling recall@10 after query expansion: 0.000000
#
#
# Query: retrieval model
# Sum pooling recall@10 after query expansion: 0.000000

# %%
for idx in range(3):
    # calculate and rank by tf_idf_weighted_pooling_score
    print("Query: %s" % query_df["query"][idx])

    documents_df = documents_df.assign(tf_idf_weighted_pooling_score=cal_cosine_scores(query_df, idx, documents_df, 'tf_idf_weighted_pooling_embedding'))
    tf_idf_weighted_pooling_sorted_results = documents_df.sort_values("tf_idf_weighted_pooling_score", ascending=False)
        
    tf_idf_weighted_pooling_recall_10 = recall_10(query_df, idx, tf_idf_weighted_pooling_sorted_results)
    print("TF-IDF weighted pooling recall@10 after query expansion: %f \r\n\r\n" % tf_idf_weighted_pooling_recall_10)
# Out:
# Query: relational database
# TF-IDF weighted pooling recall@10 after query expansion: 0.000000
#
#
# Query: garbage collection
# TF-IDF weighted pooling recall@10 after query expansion: 0.000000
#
#
# Query: retrieval model
# TF-IDF weighted pooling recall@10 after query expansion: 0.000000

# %% [markdown]
# ### Discussion
# Why we measure recall here instead of precision or NDCG?
#
# **Answer:**
#
# Because different queries have different numbers of related documents. The query with more related documents may have a larger precision or NDCG. So in order to eliminate the influence of this factor when comparing the results before query expansion and after query expansion, we'd better use recall instead of precision or NDCG.

# %% [markdown]
# Should the tokens added for expansion have the same importance as the original query tokens? If not, how to improve the query expansion in this part?
#
# **Answer:**
#
# Maybe not. We can reduce the weights of the query expansion words in aggregating the query embedding.
